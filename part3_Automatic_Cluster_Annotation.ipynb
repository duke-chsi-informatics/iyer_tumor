# %% [markdown]
# We use SCSA to help annotate the clusters. SCSA annotation is based on a few manually curated database. Instructions can be found https://github.com/bioinfo-ibms-pumc/SCSA.

# %%
cd /SCSA

# %%
python3 SCSA.py -d whole.db -i /scratch/umap_cluster.csv -s scanpy -E -f1.5 -p 0.01 -o /scratch/umap_annotation_result -m txt
# Out:
# DB load: 47347 3 3 48257 37440
# Namespace(Gensymbol=True, MarkerDB=None, celltype='normal', cluster='all', db='whole.db', foldchange=1.5, input='/scratch/umap_cluster.csv', list_tissue=False, noprint=False, norefdb=False, outfmt='txt', output='/scratch/umap_annotation_result', pvalue=0.01, source='scanpy', species='Human', target='cellmarker', tissue='All', weight=100.0)
# DB load: 47347 3 3 48257 37440
# load markers: 45409
# ############################## Cluster 0 ##############################
#
# Cell Num: 112
# Gene Num: 59
# Not Zero: 322
# Cluster 0 Gene number: 64
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                     T cell            5.7127    1.2
# ------------------------------------------------------------
#           (Natural killer T (NKT) cell)(4.8926)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 59 Group2: 1131
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                 go_name
#  GO:0003746         5              6  0.000093  0.012741   *  translation elongation factor activity
#  GO:0005164         3              4  0.003518  0.240968   -  tumor necrosis factor receptor binding
#  GO:0005125         4             12  0.006346  0.289778   -                       cytokine activity
#  GO:0035591         2              2  0.013599  0.339834   -              signaling adaptor activity
#  GO:0008289         3              8  0.014380  0.339834   -                           lipid binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                             go_name
#  GO:0005853         3              3  0.002083  0.225016   -  eukaryotic translation elongation factor 1 complex
#  GO:0005667         5             18  0.004268  0.230462   -                        transcription factor complex
#  GO:0030665         2              5  0.043220  0.592280   -                    clathrin-coated vesicle membrane
#  GO:0005758         2              6  0.055817  0.592280   -                   mitochondrial intermembrane space
#  GO:0005634        26            376  0.059831  0.592280   -                                             nucleus
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                           go_name
#  GO:0006414         5              5  0.000053  0.026205   *                          translational elongation
#  GO:0060070         3              2  0.001080  0.268333   -                   canonical Wnt signaling pathway
#  GO:0045060         3              5  0.005431  0.312210   -                  negative thymic T cell selection
#  GO:0071345         3              5  0.005431  0.312210   -            cellular response to cytokine stimulus
#  GO:0006357         8             50  0.006120  0.312210   -  regulation of transcription by RNA polymerase II
#
# Other Gene number: 1131
# ############################## Cluster 1 ##############################
#
# Cell Num: 78
# Gene Num: 23
# Not Zero: 136
# Cluster 1 Gene number: 26
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                Microglial cell        4.9092    1.5
# ------------------------------------------------------------
#             (Hematopoietic stem cell)  (3.3659)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 23 Group2: 1146
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                     go_name
#  GO:0004857         2              1  0.001098  0.080185   -                   enzyme inhibitor activity
#  GO:0043130         2              8  0.015146  0.189699   -                           ubiquitin binding
#  GO:0004930         2             12  0.029198  0.189699   -         G protein-coupled receptor activity
#  GO:0000175         1              1  0.038979  0.189699   -              3'-5'-exoribonuclease activity
#  GO:0038147         1              1  0.038979  0.189699   -  C-X-C motif chemokine 12 receptor activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                           go_name
#  GO:0005575         2              7  0.012263  0.333333   -                cellular_component
#  GO:0031514         1              1  0.038979  0.333333   -                     motile cilium
#  GO:0016529         1              1  0.038979  0.333333   -            sarcoplasmic reticulum
#  GO:0014731         1              1  0.038979  0.333333   -  spectrin-associated cytoskeleton
#  GO:0043194         1              1  0.038979  0.333333   -              axon initial segment
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                          go_name
#  GO:0009615         4             27  0.002523  0.177022   -                                response to virus
#  GO:0006955         6             70  0.002572  0.177022   -                                  immune response
#  GO:0060337         3             16  0.005255  0.177022   -              type I interferon signaling pathway
#  GO:0051607         3             21  0.010290  0.177022   -                        defense response to virus
#  GO:0045071         2              8  0.015146  0.177022   -  negative regulation of viral genome replication
#
# Other Gene number: 1146
# ############################## Cluster 10 ##############################
#
# Cell Num: 176
# Gene Num: 76
# Not Zero: 575
# Cluster 10 Gene number: 81
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?            Regulatory T (Treg) cell   8.4017    1.1
# ------------------------------------------------------------
#                     (T cell)           (7.3576)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 76 Group2: 1107
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                    go_name
#  GO:0038023         8             19  0.000165  0.023613   *                signaling receptor activity
#  GO:0004950         3              1  0.000974  0.069661   -                chemokine receptor activity
#  GO:0004888         7             22  0.001697  0.077011   -  transmembrane signaling receptor activity
#  GO:0042802        16            102  0.002154  0.077011   -                  identical protein binding
#  GO:0016493         3              5  0.011294  0.257085   -            C-C chemokine receptor activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                    go_name
#  GO:0009897        17             69  0.000011  0.001102  **           external side of plasma membrane
#  GO:0005887        17            108  0.001471  0.073535   -      integral component of plasma membrane
#  GO:0042101         3              7  0.022038  0.551100   -                    T cell receptor complex
#  GO:0098636         2              2  0.022462  0.551100   -  protein complex involved in cell adhesion
#  GO:0005886        34            367  0.027882  0.551100   -                            plasma membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                           go_name
#  GO:0006955        16             62  0.000013  0.006286  **                                   immune response
#  GO:0033209         8             13  0.000021  0.006286  **  tumor necrosis factor-mediated signaling pathway
#  GO:0045589         5              4  0.000099  0.019958   *   regulation of regulatory T cell differentiation
#  GO:0097190         5              6  0.000327  0.044198   *                       apoptotic signaling pathway
#  GO:0042110         7             16  0.000365  0.044198   *                                 T cell activation
#
# Other Gene number: 1107
# ############################## Cluster 11 ##############################
#
# Cell Num: 5
# Gene Num: 4
# Not Zero: 7
# Cluster 11 Gene number: 11
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good       Natural killer T (NKT) cell  1.7885    4.1
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 4 Group2: 1152
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                                   go_name
#  GO:0003674         2             20  0.002028  0.010142   *                                                        molecular_function
#  GO:0005198         2             20  0.002028  0.010142   *                                              structural molecule activity
#  GO:0001012         1              1  0.006911  0.023038   *                           RNA polymerase II regulatory region DNA binding
#  GO:0004715         1              9  0.034200  0.085499   -                    non-membrane spanning protein tyrosine kinase activity
#  GO:0001228         1             46  0.153164  0.257654   -  DNA-binding transcription activator activity, RNA polymerase II-specific
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                go_name
#  GO:0045095         2              5  0.000188  0.001126  **       keratin filament
#  GO:0005634         3            382  0.110470  0.331410   -                nucleus
#  GO:0070062         2            314  0.301548  0.603097   -  extracellular exosome
#  GO:0005829         2            418  0.460684  0.691025   -                cytosol
#  GO:0005737         1            355  0.771165  0.803665   -              cytoplasm
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                             go_name
#  GO:0008150         2             17  0.001507  0.009846  **                                                  biological_process
#  GO:0031424         2             17  0.001507  0.009846  **                                                      keratinization
#  GO:0070268         2             19  0.001846  0.009846  **                                                       cornification
#  GO:0060335         1              1  0.006911  0.027646   *  positive regulation of interferon-gamma-mediated signaling pathway
#  GO:0007202         1              4  0.017211  0.055076   -                              activation of phospholipase C activity
#
# Other Gene number: 1152
# ############################## Cluster 12 ##############################
#
# Cell Num: 98
# Gene Num: 85
# Not Zero: 281
# Cluster 12 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good                Basal cell          8.9333    2.6
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 85 Group2: 1115
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                          go_name
#  GO:0005200         9             17  0.000034  0.005862  **           structural constituent of cytoskeleton
#  GO:0045296        13             48  0.000181  0.015573   *                                 cadherin binding
#  GO:0098641         5              8  0.001299  0.056097   -  cadherin binding involved in cell-cell adhesion
#  GO:0043325         3              1  0.001305  0.056097   -    phosphatidylinositol-3,4-bisphosphate binding
#  GO:0005544         4              6  0.003546  0.121988   -           calcium-dependent phospholipid binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value  sig                go_name
#  GO:0030057         7              5  0.000004  0.000647  ***              desmosome
#  GO:0070062        43            299  0.000007  0.000647  ***  extracellular exosome
#  GO:0001533         6              7  0.000122  0.007880   **     cornified envelope
#  GO:0030054        10             28  0.000172  0.008327   **          cell junction
#  GO:0005882         7             13  0.000255  0.009893   **  intermediate filament
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                 go_name
#  GO:0031424        13             15  7.181397e-09  0.000005  ***          keratinization
#  GO:0070268        13             17  2.043786e-08  0.000007  ***           cornification
#  GO:0008544         6             10  4.777017e-04  0.112578    -   epidermis development
#  GO:0098609         8             26  1.805933e-03  0.319199    -      cell-cell adhesion
#  GO:0001765         3              2  3.094386e-03  0.393133    -  membrane raft assembly
#
# Other Gene number: 1115
# ############################## Cluster 13 ##############################
#
# Cell Num: 76
# Gene Num: 93
# Not Zero: 293
# Cluster 13 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good       Natural killer T (NKT) cell  6.3422    2.1
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 93 Group2: 1086
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                      go_name
#  GO:0003723        27            103  4.547904e-07  0.000076  ***                  RNA binding
#  GO:0003697         7              4  3.885045e-06  0.000324  ***  single-stranded DNA binding
#  GO:0005515        82            748  2.318126e-05  0.001290   **              protein binding
#  GO:0042393         5              4  2.689022e-04  0.008005   **              histone binding
#  GO:0031492         5              4  2.689022e-04  0.008005   **      nucleosomal DNA binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                           go_name
#  GO:0005634        68            332  9.006965e-16  1.657282e-13  ***                           nucleus
#  GO:0005654        46            181  5.220487e-12  4.802848e-10  ***                       nucleoplasm
#  GO:0000777         6              1  1.356595e-06  8.320452e-05  ***  condensed chromosome kinetochore
#  GO:0071013         8              6  2.267142e-06  1.042885e-04  ***      catalytic step 2 spliceosome
#  GO:0000785         9             10  3.872014e-06  1.245082e-04  ***                         chromatin
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                                 go_name
#  GO:0051301        20              6  1.793564e-18  1.070758e-15  ***                                           cell division
#  GO:0006325         7              4  3.885045e-06  9.044443e-04  ***                                  chromatin organization
#  GO:0000278         8              7  4.544946e-06  9.044443e-04  ***                                      mitotic cell cycle
#  GO:0000398        10             15  7.043670e-06  1.051268e-03   **                          mRNA splicing, via spliceosome
#  GO:0031145         6              3  1.427709e-05  1.704685e-03   **  anaphase-promoting complex-dependent catabolic process
# Other Gene number: 1086
# ############################## Cluster 14 ##############################
#
# Cell Num: 133
# Gene Num: 87
# Not Zero: 398
# Cluster 14 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?             Mesenchymal stem cell     7.6170    1.9
# ------------------------------------------------------------
#                    (Stem cell)         (4.0693)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 87 Group2: 1100
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                                                  go_name
#  GO:0005201        13              9  2.116300e-10  3.301428e-08  ***                              extracellular matrix structural constituent
#  GO:0030020         5              1  1.072736e-05  8.367340e-04  ***  extracellular matrix structural constituent conferring tensile strength
#  GO:0005178         7             17  1.108040e-03  4.618698e-02    *                                                         integrin binding
#  GO:0005518         6             12  1.184282e-03  4.618698e-02    *                                                         collagen binding
#  GO:0008201         6             13  1.629946e-03  5.085432e-02    -                                                          heparin binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                   go_name
#  GO:0062023        20             37  3.240627e-10  6.384035e-08  ***  collagen-containing extracellular matrix
#  GO:0005788        17             33  1.517161e-08  1.494404e-06  ***               endoplasmic reticulum lumen
#  GO:0005576        33            150  7.248463e-08  4.759824e-06  ***                      extracellular region
#  GO:0031012         9              6  1.419740e-07  6.992221e-06  ***                      extracellular matrix
#  GO:0005615        30            134  2.712581e-07  1.068757e-05  ***                       extracellular space
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                  go_name
#  GO:0030198        14             23  7.067832e-08  0.000049  ***        extracellular matrix organization
#  GO:0044267        11             23  1.241697e-05  0.004284   **       cellular protein metabolic process
#  GO:0043687        11             26  3.085604e-05  0.007097   **  post-translational protein modification
#  GO:0030449         6              7  1.479352e-04  0.020415    *      regulation of complement activation
#  GO:0001501         6              7  1.479352e-04  0.020415    *              skeletal system development
#
# Other Gene number: 1100
# ############################## Cluster 15 ##############################
#
# Cell Num: 40
# Gene Num: 91
# Not Zero: 202
# Cluster 15 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                   Astrocyte           4.1947    1.1
# ------------------------------------------------------------
#           (Natural killer T (NKT) cell)(3.7277)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 91 Group2: 1086
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                              go_name
#  GO:0008233         5              6  0.000789  0.085238   -                                                   peptidase activity
#  GO:0004579         3              1  0.001692  0.091365   -  dolichyl-diphosphooligosaccharide-protein glycotransferase activity
#  GO:0003674         6             17  0.006235  0.224464   -                                                   molecular_function
#  GO:0015037         2              1  0.016855  0.290533   -                            peptide disulfide oxidoreductase activity
#  GO:0005046         2              1  0.016855  0.290533   -                                                KDEL sequence binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                               go_name
#  GO:0005789        35             61  9.395279e-18  1.136829e-15  ***                        endoplasmic reticulum membrane
#  GO:0005783        35             79  5.379441e-15  3.254562e-13  ***                                 endoplasmic reticulum
#  GO:0005793         9              5  9.772079e-08  3.941405e-06  ***  endoplasmic reticulum-Golgi intermediate compartment
#  GO:0030134         6              3  1.266777e-05  2.668131e-04  ***            COPII-coated ER to Golgi transport vesicle
#  GO:0008250         5              1  1.403576e-05  2.668131e-04  ***                     oligosaccharyltransferase complex
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                                                go_name
#  GO:0006888        12             13  5.066120e-08  0.000023  ***              endoplasmic reticulum to Golgi vesicle-mediated transport
#  GO:0006890         8              3  1.292911e-07  0.000029  ***  retrograde vesicle-mediated transport, Golgi to endoplasmic reticulum
#  GO:0036498         7              5  7.600725e-06  0.001133   **                                IRE1-mediated unfolded protein response
#  GO:0006465         5              1  1.403576e-05  0.001568   **                                              signal peptide processing
#  GO:0007030         5              2  4.612463e-05  0.003436   **                                                     Golgi organization
#
# Other Gene number: 1086
# ############################## Cluster 16 ##############################
#
# Cell Num: 148
# Gene Num: 95
# Not Zero: 501
# Cluster 16 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?          Natural killer T (NKT) cell  6.3372    1.6
# ------------------------------------------------------------
#                     (T cell)           (3.9393)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 95 Group2: 1122
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                 go_name
#  GO:0003723        34            109  1.057830e-10  2.168551e-08  ***                             RNA binding
#  GO:0031625        11             37  7.325012e-04  4.243205e-02    *        ubiquitin protein ligase binding
#  GO:0003746         5              6  8.279425e-04  4.243205e-02    *  translation elongation factor activity
#  GO:0003743         5              6  8.279425e-04  4.243205e-02    *  translation initiation factor activity
#  GO:0036002         3              1  1.742532e-03  7.144381e-02    -                        pre-mRNA binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                               go_name
#  GO:0005634        53            365  0.000007  0.001233  **                               nucleus
#  GO:1990904         9             17  0.000076  0.007032  **             ribonucleoprotein complex
#  GO:0005654        33            205  0.000208  0.012806   *                           nucleoplasm
#  GO:0016282         3              1  0.001743  0.080592   -  eukaryotic 43S preinitiation complex
#  GO:0071013         5             10  0.004179  0.154617   -          catalytic step 2 spliceosome
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                   go_name
#  GO:0000398        11             17  0.000003  0.001860  **                            mRNA splicing, via spliceosome
#  GO:0000381         6              3  0.000013  0.004778  **  regulation of alternative mRNA splicing, via spliceosome
#  GO:0006413         7              7  0.000031  0.007340  **                                  translational initiation
#  GO:0006397         6              7  0.000212  0.030296   *                                           mRNA processing
#  GO:0043488         7             11  0.000222  0.030296   *                              regulation of mRNA stability
#
# Other Gene number: 1122
# ############################## Cluster 17 ##############################
#
# Cell Num: 182
# Gene Num: 93
# Not Zero: 597
# Cluster 17 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                Endothelial cell       9.5561    1.7
# ------------------------------------------------------------
#              (Mesenchymal stem cell)   (5.7366)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 93 Group2: 1089
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                       go_name
#  GO:0008565         3              3  0.007926  0.351025   -                                  protein transporter activity
#  GO:0015026         5             13  0.010189  0.351025   -                                           coreceptor activity
#  GO:0043236         3              4  0.013084  0.351025   -                                               laminin binding
#  GO:0005001         2              1  0.017442  0.351025   -  transmembrane receptor protein tyrosine phosphatase activity
#  GO:0034713         2              1  0.017442  0.351025   -       type I transforming growth factor beta receptor binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                   go_name
#  GO:0005925        18             61  0.000014  0.002315  **                            focal adhesion
#  GO:0005886        50            346  0.000022  0.002315  **                           plasma membrane
#  GO:0043235         8             17  0.000386  0.025888   *                          receptor complex
#  GO:0005913         7             13  0.000495  0.025888   *               cell-cell adherens junction
#  GO:0062023        12             43  0.000713  0.029824   *  collagen-containing extracellular matrix
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                                          go_name
#  GO:0001525        17             25  2.060286e-09  0.000001  ***                                                     angiogenesis
#  GO:0007156         6              4  3.294423e-05  0.011975    *  homophilic cell adhesion via plasma membrane adhesion molecules
#  GO:0030198        11             27  8.081020e-05  0.019583    *                                extracellular matrix organization
#  GO:0001570         5              4  2.656809e-04  0.048288    *                                                   vasculogenesis
#  GO:0031623         6              8  3.628959e-04  0.052765    -                                         receptor internalization
#
# Other Gene number: 1089
# ############################## Cluster 18 ##############################
#
# Cell Num: 98
# Gene Num: 93
# Not Zero: 332
# Cluster 18 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                   Stem cell           6.7989    1.8
# ------------------------------------------------------------
#                 (Progenitor cell)      (3.8790)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 93 Group2: 1103
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                 go_name
#  GO:0003723        20            114  0.002019  0.318916   -                             RNA binding
#  GO:0097110         5              9  0.002912  0.318916   -                scaffold protein binding
#  GO:0003743         4              7  0.007401  0.396252   -  translation initiation factor activity
#  GO:0044877         6             19  0.009923  0.396252   -      protein-containing complex binding
#  GO:0005198         6             20  0.012106  0.396252   -            structural molecule activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                         go_name
#  GO:0005882         7             10  0.000141  0.015306   *                           intermediate filament
#  GO:0016327         4              1  0.000162  0.015306   *                    apicolateral plasma membrane
#  GO:0070062        42            296  0.000218  0.015306   *                           extracellular exosome
#  GO:0005829        50            394  0.000496  0.026171   *                                         cytosol
#  GO:0019773         3              1  0.001722  0.072658   -  proteasome core complex, alpha-subunit complex
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                       go_name
#  GO:0070268         7             18  0.002066  0.421766   -                 cornification
#  GO:0007219         4              8  0.010447  0.421766   -       Notch signaling pathway
#  GO:0030216         4              9  0.014205  0.421766   -  keratinocyte differentiation
#  GO:0006413         4              9  0.014205  0.421766   -      translational initiation
#  GO:0045214         2              1  0.017047  0.421766   -        sarcomere organization
#
# Other Gene number: 1103
# ############################## Cluster 19 ##############################
#
# Cell Num: 125
# Gene Num: 94
# Not Zero: 428
# Cluster 19 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good                  B cell            8.9245    2.4
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 94 Group2: 1109
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                                go_name
#  GO:0000978        11             51  0.006536  0.475804   -      RNA polymerase II proximal promoter sequence-specific DNA binding
#  GO:0003677        12             64  0.011775  0.475804   -                                                            DNA binding
#  GO:0000981        13             73  0.012645  0.475804   -  DNA-binding transcription factor activity, RNA polymerase II-specific
#  GO:0070888         3              5  0.019392  0.475804   -                                                          E-box binding
#  GO:0043425         2              2  0.032674  0.475804   -                                      bHLH transcription factor binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                          go_name
#  GO:0048471        14             79  0.010025  0.561359   -  perinuclear region of cytoplasm
#  GO:0035578         4             10  0.019039  0.561359   -          azurophil granule lumen
#  GO:0005783        15             99  0.025653  0.561359   -            endoplasmic reticulum
#  GO:0005788         8             41  0.031920  0.561359   -      endoplasmic reticulum lumen
#  GO:0005789        13             84  0.032553  0.561359   -   endoplasmic reticulum membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                            go_name
#  GO:0120162         5             10  0.004194  0.400321   -  positive regulation of cold-induced thermogenesis
#  GO:0071333         4              7  0.007533  0.400321   -              cellular response to glucose stimulus
#  GO:0048146         4              7  0.007533  0.400321   -    positive regulation of fibroblast proliferation
#  GO:0050885         3              3  0.007775  0.400321   -          neuromuscular process controlling balance
#  GO:0032148         3              3  0.007775  0.400321   -            activation of protein kinase B activity
#
# Other Gene number: 1109
# ############################## Cluster 2 ##############################
#
# Cell Num: 106
# Gene Num: 44
# Not Zero: 278
# Cluster 2 Gene number: 46
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                Microglial cell        6.0544    1.2
# ------------------------------------------------------------
#                     (T cell)           (4.8447)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 44 Group2: 1139
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                go_name
#  GO:0043548         3              5  0.002362  0.134133   -  phosphatidylinositol 3-kinase binding
#  GO:0042288         3              6  0.003451  0.134133   -            MHC class I protein binding
#  GO:0008009         3              8  0.006433  0.134133   -                     chemokine activity
#  GO:0004252         4             18  0.007469  0.134133   -     serine-type endopeptidase activity
#  GO:0031726         2              2  0.007738  0.134133   -        CCR1 chemokine receptor binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                           go_name
#  GO:0005576        16            168  0.000465  0.033940   *              extracellular region
#  GO:0042101         3              7  0.004803  0.175306   -           T cell receptor complex
#  GO:0009897         8             76  0.009913  0.241226   -  external side of plasma membrane
#  GO:0001772         3             12  0.015981  0.291659   -             immunological synapse
#  GO:0042612         2              5  0.025217  0.322557   -       MHC class I protein complex
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                           go_name
#  GO:0006955        11             69  0.000084  0.031647   *                                                   immune response
#  GO:0050776         8             42  0.000318  0.059977   -                                     regulation of immune response
#  GO:0002250         6             28  0.001150  0.144491   -                                          adaptive immune response
#  GO:0045954         3              5  0.002362  0.178103   -  positive regulation of natural killer cell mediated cytotoxicity
#  GO:0019835         3              5  0.002362  0.178103   -                                                         cytolysis
#
# Other Gene number: 1139
# ############################## Cluster 20 ##############################
#
# Cell Num: 97
# Gene Num: 55
# Not Zero: 265
# Cluster 20 Gene number: 62
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good           Natural killer cell      8.5605    2.5
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 55 Group2: 1126
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                    go_name
#  GO:0004888         7             23  0.000286  0.027400   *  transmembrane signaling receptor activity
#  GO:1990405         3              2  0.000896  0.027400   *                    protein antigen binding
#  GO:0023024         3              2  0.000896  0.027400   *        MHC class I protein complex binding
#  GO:0030246         6             21  0.001075  0.027400   *                       carbohydrate binding
#  GO:0017091         2              2  0.012033  0.154205   -                    AU-rich element binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                     go_name
#  GO:0043235         4             21  0.025676  0.637071   -                                            receptor complex
#  GO:0031234         2              8  0.075399  0.637071   -  extrinsic component of cytoplasmic side of plasma membrane
#  GO:0016021        16            228  0.082694  0.637071   -                              integral component of membrane
#  GO:0000178         1              1  0.091010  0.637071   -                                     exosome (RNase complex)
#  GO:0098745         1              1  0.091010  0.637071   -                                           Dcp1-Dcp2 complex
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                     go_name
#  GO:0050776         8             40  0.001167  0.298577   -                               regulation of immune response
#  GO:0006968         5             16  0.002097  0.298577   -                                   cellular defense response
#  GO:0042119         2              1  0.006202  0.298577   -                                       neutrophil activation
#  GO:2000556         2              1  0.006202  0.298577   -  positive regulation of T-helper 1 cell cytokine production
#  GO:0002228         2              1  0.006202  0.298577   -                       natural killer cell mediated immunity
#
# Other Gene number: 1126
# ############################## Cluster 21 ##############################
#
# Cell Num: 118
# Gene Num: 87
# Not Zero: 331
# Cluster 21 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                   Mast cell           7.3203    1.6
# ------------------------------------------------------------
#             (Hematopoietic stem cell)  (4.6294)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 87 Group2: 1093
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                   go_name
#  GO:0046872        15             80  0.002651  0.264554   -                         metal ion binding
#  GO:0005524        13             67  0.004047  0.264554   -                               ATP binding
#  GO:0004674         5             11  0.004434  0.264554   -  protein serine/threonine kinase activity
#  GO:0017049         2              1  0.015358  0.363318   -                           GTP-Rho binding
#  GO:0005506         2              1  0.015358  0.363318   -                          iron ion binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                 go_name
#  GO:0031088         2              1  0.015358  0.588465   -                         platelet dense granule membrane
#  GO:0044233         2              1  0.015358  0.588465   -  mitochondria-associated endoplasmic reticulum membrane
#  GO:0008021         3              5  0.016535  0.588465   -                                        synaptic vesicle
#  GO:0031965         5             17  0.018774  0.588465   -                                        nuclear membrane
#  GO:0005635         5             17  0.018774  0.588465   -                                        nuclear envelope
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                      go_name
#  GO:0042759         3              1  0.001469  0.402619   -                   long-chain fatty acid biosynthetic process
#  GO:0051968         3              1  0.001469  0.402619   -  positive regulation of synaptic transmission, glutamatergic
#  GO:0019371         3              2  0.003477  0.402619   -                                       cyclooxygenase pathway
#  GO:0019370         3              3  0.006584  0.402619   -                             leukotriene biosynthetic process
#  GO:0006468         7             26  0.008183  0.402619   -                                      protein phosphorylation
#
# Other Gene number: 1093
# ############################## Cluster 3 ##############################
#
# Cell Num: 81
# Gene Num: 24
# Not Zero: 169
# Cluster 3 Gene number: 32
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                     T cell            4.8948    1.3
# ------------------------------------------------------------
#               (Natural killer cell)    (3.9133)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 24 Group2: 1148
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                    go_name
#  GO:0004888         4             26  0.002600  0.124302   -  transmembrane signaling receptor activity
#  GO:0017124         3             13  0.003551  0.124302   -                         SH3 domain binding
#  GO:0004252         3             19  0.009006  0.166985   -         serine-type endopeptidase activity
#  GO:0008009         2              9  0.019756  0.166985   -                         chemokine activity
#  GO:0031698         1              1  0.040553  0.166985   -         beta-2 adrenergic receptor binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                            go_name
#  GO:0001772         3             12  0.002925  0.106588   -              immunological synapse
#  GO:0009897         6             76  0.004737  0.106588   -   external side of plasma membrane
#  GO:0005886        13            382  0.029775  0.304151   -                    plasma membrane
#  GO:0045334         1              1  0.040553  0.304151   -  clathrin-coated endocytic vesicle
#  GO:0032590         1              1  0.040553  0.304151   -                  dendrite membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                          go_name
#  GO:0019835         3              6  0.000586  0.124746   -                                        cytolysis
#  GO:0002544         2              1  0.001192  0.126296   -                    chronic inflammatory response
#  GO:0070234         2              2  0.002353  0.126296   -  positive regulation of T cell apoptotic process
#  GO:0070098         3             11  0.002372  0.126296   -             chemokine-mediated signaling pathway
#  GO:0008626         2              3  0.003873  0.126673   -    granzyme-mediated apoptotic signaling pathway
#
# Other Gene number: 1148
# ############################## Cluster 4 ##############################
#
# Cell Num: 106
# Gene Num: 87
# Not Zero: 411
# Cluster 4 Gene number: 95
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good                  B cell            10.0021   8.7
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 87 Group2: 1094
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                     go_name
#  GO:0032395         5              3  0.000091  0.012389   *              MHC class II receptor activity
#  GO:0023026         6             11  0.000861  0.055139   -        MHC class II protein complex binding
#  GO:0042605         6             12  0.001216  0.055139   -                     peptide antigen binding
#  GO:0005085         3              6  0.023443  0.616548   -  guanyl-nucleotide exchange factor activity
#  GO:0035091         2              2  0.029200  0.616548   -                phosphatidylinositol binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                     go_name
#  GO:0042613         9              7  3.187256e-07  0.000043  ***                MHC class II protein complex
#  GO:0030658         7              6  1.110495e-05  0.000755  ***                  transport vesicle membrane
#  GO:0030669         7              7  2.088795e-05  0.000947  ***  clathrin-coated endocytic vesicle membrane
#  GO:0005765        11             28  5.605038e-05  0.001906   **                          lysosomal membrane
#  GO:0032588         7             10  9.847567e-05  0.002679   **                trans-Golgi network membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                                                            go_name
#  GO:0050853         9              6  1.483330e-07  0.000073  ***                                                  B cell receptor signaling pathway
#  GO:0006959         9              9  1.197055e-06  0.000295  ***                                                            humoral immune response
#  GO:0042113         6              2  3.364376e-06  0.000553  ***                                                                  B cell activation
#  GO:0019886         9             13  9.563572e-06  0.001179   **  antigen processing and presentation of exogenous peptide antigen via MHC class II
#  GO:0042100         5              5  3.638501e-04  0.035876    *                                                               B cell proliferation
#
# Other Gene number: 1094
# ############################## Cluster 5 ##############################
#
# !WARNING3:Zero marker sets found, type:marker
# !WARNING3:Change the threshold or tissue name and try again?
# !WARNING3:EnsemblID or GeneID,try '-E' command?
# Cluster 5 Gene number: 0
# None
# !WARNING(go processing):Zero gene sets found for the cluster 5
# !WARNING(go processing):Change the threshold and try again?
# Other Gene number: 1155
# ############################## Cluster 6 ##############################
#
# Cell Num: 127
# Gene Num: 96
# Not Zero: 510
# Cluster 6 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good                  B cell            9.1003    2.2
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 96 Group2: 1087
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                               go_name
#  GO:0042605         6             13  0.002784  0.469982   -               peptide antigen binding
#  GO:0005543         3              3  0.008654  0.469982   -                  phospholipid binding
#  GO:0030145         3              3  0.008654  0.469982   -                 manganese ion binding
#  GO:0023026         5             13  0.011603  0.469982   -  MHC class II protein complex binding
#  GO:0001664         3              4  0.014259  0.469982   -    G protein-coupled receptor binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                       go_name
#  GO:0005765        11             29  0.000181  0.010539   *            lysosomal membrane
#  GO:0042613         7             10  0.000185  0.010539   *  MHC class II protein complex
#  GO:1904724         6              7  0.000264  0.010539   *        tertiary granule lumen
#  GO:0032588         7             11  0.000283  0.010539   *  trans-Golgi network membrane
#  GO:0030658         6              8  0.000431  0.012851   *    transport vesicle membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                                            go_name
#  GO:0043312        22             75  0.000002  0.001743  **                                                           neutrophil degranulation
#  GO:0019886         9             15  0.000050  0.017593   *  antigen processing and presentation of exogenous peptide antigen via MHC class II
#  GO:0006954        12             47  0.001843  0.277042   -                                                              inflammatory response
#  GO:0030225         3              1  0.001954  0.277042   -                                                         macrophage differentiation
#  GO:0002430         3              1  0.001954  0.277042   -                                     complement receptor mediated signaling pathway
#
# Other Gene number: 1087
# ############################## Cluster 7 ##############################
#
# Cell Num: 156
# Gene Num: 95
# Not Zero: 619
# Cluster 7 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                     T cell            7.5330    1.3
# ------------------------------------------------------------
#               (Natural killer cell)    (5.6587)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 95 Group2: 1121
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                    go_name
#  GO:0042608         4              2  0.000465  0.094952   -                    T cell receptor binding
#  GO:0042605         6             13  0.002290  0.221036   -                    peptide antigen binding
#  GO:0042288         4              5  0.003251  0.221036   -                MHC class I protein binding
#  GO:0003785         3              3  0.007773  0.385761   -                      actin monomer binding
#  GO:0004888         7             25  0.009455  0.385761   -  transmembrane signaling receptor activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value  sig                           go_name
#  GO:0005886        54            368  0.000004  0.000589  ***                   plasma membrane
#  GO:0016020        33            194  0.000077  0.005088   **                          membrane
#  GO:0009897        18             73  0.000104  0.005088   **  external side of plasma membrane
#  GO:0042101         6              6  0.000123  0.005088   **           T cell receptor complex
#  GO:0030670         7             14  0.000669  0.022203    *       phagocytic vesicle membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                  go_name
#  GO:0050776        18             41  1.140362e-07  0.000083  ***            regulation of immune response
#  GO:0007166        15             43  1.511970e-05  0.005526   **  cell surface receptor signaling pathway
#  GO:0042110         9             15  3.655430e-05  0.008907   **                        T cell activation
#  GO:0002250        10             28  3.972904e-04  0.058852    -                 adaptive immune response
#  GO:0006955        16             68  4.259004e-04  0.058852    -                          immune response
#
# Other Gene number: 1121
# ############################## Cluster 8 ##############################
#
# Cell Num: 134
# Gene Num: 93
# Not Zero: 371
# Cluster 8 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                   Basal cell          6.1827    1.4
# ------------------------------------------------------------
#               (Embryonic stem cell)    (4.4368)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 93 Group2: 1099
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                  go_name
#  GO:0008106         5              1  0.000015  0.002236  **   alcohol dehydrogenase (NADP+) activity
#  GO:0004032         4              1  0.000164  0.012462   *  alditol:NADP+ 1-oxidoreductase activity
#  GO:0016491         5              4  0.000255  0.012934   *                  oxidoreductase activity
#  GO:0005198         8             20  0.000859  0.032655   *             structural molecule activity
#  GO:0004033         3              1  0.001739  0.052860   -      aldo-keto reductase (NADP) activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                go_name
#  GO:0001533         5              8  0.002024  0.196852   -                     cornified envelope
#  GO:0005882         6             14  0.003039  0.196852   -                  intermediate filament
#  GO:0046658         3              2  0.004101  0.196852   -  anchored component of plasma membrane
#  GO:0030057         4              7  0.007489  0.217456   -                              desmosome
#  GO:0005615        21            140  0.008741  0.217456   -                    extracellular space
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                       go_name
#  GO:0001523         8              2  4.068159e-08  0.000026  ***    retinoid metabolic process
#  GO:0006805         7              7  3.083154e-05  0.008948   **  xenobiotic metabolic process
#  GO:0070268        10             20  4.214343e-05  0.008948   **                 cornification
#  GO:0008202         4              1  1.639709e-04  0.026112    *     steroid metabolic process
#  GO:0008544         6              9  5.414696e-04  0.068983    -         epidermis development
#
# Other Gene number: 1099
# ############################## Cluster 9 ##############################
#
# Cell Num: 100
# Gene Num: 73
# Not Zero: 324
# Cluster 9 Gene number: 80
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?          Natural killer T (NKT) cell  4.6207    1.0
# ------------------------------------------------------------
#                     (T cell)           (4.5446)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 73 Group2: 1121
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                           go_name
#  GO:0051082        15             15  1.107050e-11  2.003760e-09  ***          unfolded protein binding
#  GO:0051087        10             13  2.384511e-07  2.157982e-05  ***                 chaperone binding
#  GO:0005524        18             65  6.056179e-07  3.653894e-05  ***                       ATP binding
#  GO:0031625        13             34  1.534542e-06  6.943803e-05  ***  ubiquitin protein ligase binding
#  GO:0042623         6              3  3.101374e-06  1.122697e-04  ***          ATPase activity, coupled
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                     go_name
#  GO:0008180         4              3  0.000392  0.024539   *            COP9 signalosome
#  GO:0032991        13             65  0.000518  0.024539   *  protein-containing complex
#  GO:0043209         8             25  0.000535  0.024539   *               myelin sheath
#  GO:0101031         3              1  0.000840  0.024539   *           chaperone complex
#  GO:0016234         3              1  0.000840  0.024539   *              inclusion body
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                         go_name
#  GO:0006986        13              9  1.840716e-11  1.222235e-08  ***                    response to unfolded protein
#  GO:1900034         9              8  1.200890e-07  3.986956e-05  ***         regulation of cellular response to heat
#  GO:0051085         7              4  6.530521e-07  1.445422e-04  ***  chaperone cofactor-dependent protein refolding
#  GO:0051131         6              3  3.101374e-06  5.148280e-04  ***     chaperone-mediated protein complex assembly
#  GO:0042026         7              7  5.848283e-06  7.766520e-04  ***                               protein refolding
#
# Other Gene number: 1121
# ################################################################################
#
# #Cluster Type Celltype Score Times
# ['0', '?', 'T cell|Natural killer T (NKT) cell', '5.712727202777739|4.892631728160635', 1.1676184761458464]
# ['1', '?', 'Microglial cell|Hematopoietic stem cell', '4.9092118585182565|3.365902893623283', 1.4585126231118486]
# ['10', '?', 'Regulatory T (Treg) cell|T cell', '8.401687869071866|7.3575586977869225', 1.1419124487038081]
# ['11', 'Good', 'Natural killer T (NKT) cell', 1.7884974306693864, 4.105908458170588]
# ['12', 'Good', 'Basal cell', 8.933274339696899, 2.6127750261093983]
# ['13', 'Good', 'Natural killer T (NKT) cell', 6.342198127983272, 2.1404190021875396]
# ['14', '?', 'Mesenchymal stem cell|Stem cell', '7.616968367451205|4.069285794842815', 1.8718194669699837]
# ['15', '?', 'Astrocyte|Natural killer T (NKT) cell', '4.194690400640201|3.72774143481479', 1.1252632388782111]
# ['16', '?', 'Natural killer T (NKT) cell|T cell', '6.337216375527772|3.93928418346237', 1.6087228238399847]
# ['17', '?', 'Endothelial cell|Mesenchymal stem cell', '9.556139923846047|5.736570753736374', 1.665827954378823]
# ['18', '?', 'Stem cell|Progenitor cell', '6.798889229477258|3.879032312768262', 1.752728175812809]
# ['19', 'Good', 'B cell', 8.924533246782545, 2.4278326355814506]
# ['2', '?', 'Microglial cell|T cell', '6.054435799568078|4.844725563158944', 1.249696338964628]
# ['20', 'Good', 'Natural killer cell', 8.560466968658199, 2.524603191469]
# ['21', '?', 'Mast cell|Hematopoietic stem cell', '7.320327142744506|4.6293989466416905', 1.5812694535766674]
# ['3', '?', 'T cell|Natural killer cell', '4.89477522204045|3.913269972025537', 1.2508146018627175]
# ['4', 'Good', 'B cell', 10.002051239667471, 8.719888378272737]
# ['5', 'N', '-', '-', '-']
# ['6', 'Good', 'B cell', 9.100297135359462, 2.177966017963127]
# ['7', '?', 'T cell|Natural killer cell', '7.532985213457449|5.6587393670026875', 1.3312126120145924]
# ['8', '?', 'Basal cell|Embryonic stem cell', '6.182744173606671|4.436823162116818', 1.39350700888806]
# ['9', '?', 'Natural killer T (NKT) cell|T cell', '4.620663226024971|4.54455832942258', 1.0167463790946787]

# %%
python3 SCSA.py -d whole.db -i /scratch/tsne_cluster.csv -s scanpy -E -f1.5 -p 0.01 -o /scratch/tsne_annotation_result -m txt
# Out:
# DB load: 47347 3 3 48257 37440
# Namespace(Gensymbol=True, MarkerDB=None, celltype='normal', cluster='all', db='whole.db', foldchange=1.5, input='/scratch/tsne_cluster.csv', list_tissue=False, noprint=False, norefdb=False, outfmt='txt', output='/scratch/tsne_annotation_result', pvalue=0.01, source='scanpy', species='Human', target='cellmarker', tissue='All', weight=100.0)
# DB load: 47347 3 3 48257 37440
# load markers: 45409
# ############################## Cluster 0 ##############################
#
# Cell Num: 112
# Gene Num: 59
# Not Zero: 322
# Cluster 0 Gene number: 64
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                     T cell            5.7127    1.2
# ------------------------------------------------------------
#           (Natural killer T (NKT) cell)(4.8926)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 59 Group2: 1131
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                 go_name
#  GO:0003746         5              6  0.000093  0.012741   *  translation elongation factor activity
#  GO:0005164         3              4  0.003518  0.240968   -  tumor necrosis factor receptor binding
#  GO:0005125         4             12  0.006346  0.289778   -                       cytokine activity
#  GO:0035591         2              2  0.013599  0.339834   -              signaling adaptor activity
#  GO:0008289         3              8  0.014380  0.339834   -                           lipid binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                             go_name
#  GO:0005853         3              3  0.002083  0.225016   -  eukaryotic translation elongation factor 1 complex
#  GO:0005667         5             18  0.004268  0.230462   -                        transcription factor complex
#  GO:0030665         2              5  0.043220  0.592280   -                    clathrin-coated vesicle membrane
#  GO:0005758         2              6  0.055817  0.592280   -                   mitochondrial intermembrane space
#  GO:0005634        26            376  0.059831  0.592280   -                                             nucleus
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                           go_name
#  GO:0006414         5              5  0.000053  0.026205   *                          translational elongation
#  GO:0060070         3              2  0.001080  0.268333   -                   canonical Wnt signaling pathway
#  GO:0045060         3              5  0.005431  0.312210   -                  negative thymic T cell selection
#  GO:0071345         3              5  0.005431  0.312210   -            cellular response to cytokine stimulus
#  GO:0006357         8             50  0.006120  0.312210   -  regulation of transcription by RNA polymerase II
#
# Other Gene number: 1131
# ############################## Cluster 1 ##############################
#
# Cell Num: 78
# Gene Num: 23
# Not Zero: 136
# Cluster 1 Gene number: 26
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                Microglial cell        4.9092    1.5
# ------------------------------------------------------------
#             (Hematopoietic stem cell)  (3.3659)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 23 Group2: 1146
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                     go_name
#  GO:0004857         2              1  0.001098  0.080185   -                   enzyme inhibitor activity
#  GO:0043130         2              8  0.015146  0.189699   -                           ubiquitin binding
#  GO:0004930         2             12  0.029198  0.189699   -         G protein-coupled receptor activity
#  GO:0000175         1              1  0.038979  0.189699   -              3'-5'-exoribonuclease activity
#  GO:0038147         1              1  0.038979  0.189699   -  C-X-C motif chemokine 12 receptor activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                           go_name
#  GO:0005575         2              7  0.012263  0.333333   -                cellular_component
#  GO:0031514         1              1  0.038979  0.333333   -                     motile cilium
#  GO:0016529         1              1  0.038979  0.333333   -            sarcoplasmic reticulum
#  GO:0014731         1              1  0.038979  0.333333   -  spectrin-associated cytoskeleton
#  GO:0043194         1              1  0.038979  0.333333   -              axon initial segment
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                          go_name
#  GO:0009615         4             27  0.002523  0.177022   -                                response to virus
#  GO:0006955         6             70  0.002572  0.177022   -                                  immune response
#  GO:0060337         3             16  0.005255  0.177022   -              type I interferon signaling pathway
#  GO:0051607         3             21  0.010290  0.177022   -                        defense response to virus
#  GO:0045071         2              8  0.015146  0.177022   -  negative regulation of viral genome replication
#
# Other Gene number: 1146
# ############################## Cluster 10 ##############################
#
# Cell Num: 176
# Gene Num: 76
# Not Zero: 575
# Cluster 10 Gene number: 81
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?            Regulatory T (Treg) cell   8.4017    1.1
# ------------------------------------------------------------
#                     (T cell)           (7.3576)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 76 Group2: 1107
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                    go_name
#  GO:0038023         8             19  0.000165  0.023613   *                signaling receptor activity
#  GO:0004950         3              1  0.000974  0.069661   -                chemokine receptor activity
#  GO:0004888         7             22  0.001697  0.077011   -  transmembrane signaling receptor activity
#  GO:0042802        16            102  0.002154  0.077011   -                  identical protein binding
#  GO:0016493         3              5  0.011294  0.257085   -            C-C chemokine receptor activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                    go_name
#  GO:0009897        17             69  0.000011  0.001102  **           external side of plasma membrane
#  GO:0005887        17            108  0.001471  0.073535   -      integral component of plasma membrane
#  GO:0042101         3              7  0.022038  0.551100   -                    T cell receptor complex
#  GO:0098636         2              2  0.022462  0.551100   -  protein complex involved in cell adhesion
#  GO:0005886        34            367  0.027882  0.551100   -                            plasma membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                           go_name
#  GO:0006955        16             62  0.000013  0.006286  **                                   immune response
#  GO:0033209         8             13  0.000021  0.006286  **  tumor necrosis factor-mediated signaling pathway
#  GO:0045589         5              4  0.000099  0.019958   *   regulation of regulatory T cell differentiation
#  GO:0097190         5              6  0.000327  0.044198   *                       apoptotic signaling pathway
#  GO:0042110         7             16  0.000365  0.044198   *                                 T cell activation
#
# Other Gene number: 1107
# ############################## Cluster 11 ##############################
#
# Cell Num: 5
# Gene Num: 4
# Not Zero: 7
# Cluster 11 Gene number: 11
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good       Natural killer T (NKT) cell  1.7885    4.1
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 4 Group2: 1152
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                                   go_name
#  GO:0003674         2             20  0.002028  0.010142   *                                                        molecular_function
#  GO:0005198         2             20  0.002028  0.010142   *                                              structural molecule activity
#  GO:0001012         1              1  0.006911  0.023038   *                           RNA polymerase II regulatory region DNA binding
#  GO:0004715         1              9  0.034200  0.085499   -                    non-membrane spanning protein tyrosine kinase activity
#  GO:0001228         1             46  0.153164  0.257654   -  DNA-binding transcription activator activity, RNA polymerase II-specific
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                go_name
#  GO:0045095         2              5  0.000188  0.001126  **       keratin filament
#  GO:0005634         3            382  0.110470  0.331410   -                nucleus
#  GO:0070062         2            314  0.301548  0.603097   -  extracellular exosome
#  GO:0005829         2            418  0.460684  0.691025   -                cytosol
#  GO:0005737         1            355  0.771165  0.803665   -              cytoplasm
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                             go_name
#  GO:0008150         2             17  0.001507  0.009846  **                                                  biological_process
#  GO:0031424         2             17  0.001507  0.009846  **                                                      keratinization
#  GO:0070268         2             19  0.001846  0.009846  **                                                       cornification
#  GO:0060335         1              1  0.006911  0.027646   *  positive regulation of interferon-gamma-mediated signaling pathway
#  GO:0007202         1              4  0.017211  0.055076   -                              activation of phospholipase C activity
#
# Other Gene number: 1152
# ############################## Cluster 12 ##############################
#
# Cell Num: 98
# Gene Num: 85
# Not Zero: 281
# Cluster 12 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good                Basal cell          8.9333    2.6
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 85 Group2: 1115
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                          go_name
#  GO:0005200         9             17  0.000034  0.005862  **           structural constituent of cytoskeleton
#  GO:0045296        13             48  0.000181  0.015573   *                                 cadherin binding
#  GO:0098641         5              8  0.001299  0.056097   -  cadherin binding involved in cell-cell adhesion
#  GO:0043325         3              1  0.001305  0.056097   -    phosphatidylinositol-3,4-bisphosphate binding
#  GO:0005544         4              6  0.003546  0.121988   -           calcium-dependent phospholipid binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value  sig                go_name
#  GO:0030057         7              5  0.000004  0.000647  ***              desmosome
#  GO:0070062        43            299  0.000007  0.000647  ***  extracellular exosome
#  GO:0001533         6              7  0.000122  0.007880   **     cornified envelope
#  GO:0030054        10             28  0.000172  0.008327   **          cell junction
#  GO:0005882         7             13  0.000255  0.009893   **  intermediate filament
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                 go_name
#  GO:0031424        13             15  7.181397e-09  0.000005  ***          keratinization
#  GO:0070268        13             17  2.043786e-08  0.000007  ***           cornification
#  GO:0008544         6             10  4.777017e-04  0.112578    -   epidermis development
#  GO:0098609         8             26  1.805933e-03  0.319199    -      cell-cell adhesion
#  GO:0001765         3              2  3.094386e-03  0.393133    -  membrane raft assembly
#
# Other Gene number: 1115
# ############################## Cluster 13 ##############################
#
# Cell Num: 76
# Gene Num: 93
# Not Zero: 293
# Cluster 13 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good       Natural killer T (NKT) cell  6.3422    2.1
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 93 Group2: 1086
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                      go_name
#  GO:0003723        27            103  4.547904e-07  0.000076  ***                  RNA binding
#  GO:0003697         7              4  3.885045e-06  0.000324  ***  single-stranded DNA binding
#  GO:0005515        82            748  2.318126e-05  0.001290   **              protein binding
#  GO:0042393         5              4  2.689022e-04  0.008005   **              histone binding
#  GO:0031492         5              4  2.689022e-04  0.008005   **      nucleosomal DNA binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                           go_name
#  GO:0005634        68            332  9.006965e-16  1.657282e-13  ***                           nucleus
#  GO:0005654        46            181  5.220487e-12  4.802848e-10  ***                       nucleoplasm
#  GO:0000777         6              1  1.356595e-06  8.320452e-05  ***  condensed chromosome kinetochore
#  GO:0071013         8              6  2.267142e-06  1.042885e-04  ***      catalytic step 2 spliceosome
#  GO:0000785         9             10  3.872014e-06  1.245082e-04  ***                         chromatin
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                                 go_name
#  GO:0051301        20              6  1.793564e-18  1.070758e-15  ***                                           cell division
#  GO:0006325         7              4  3.885045e-06  9.044443e-04  ***                                  chromatin organization
#  GO:0000278         8              7  4.544946e-06  9.044443e-04  ***                                      mitotic cell cycle
#  GO:0000398        10             15  7.043670e-06  1.051268e-03   **                          mRNA splicing, via spliceosome
#  GO:0031145         6              3  1.427709e-05  1.704685e-03   **  anaphase-promoting complex-dependent catabolic process
# Other Gene number: 1086
# ############################## Cluster 14 ##############################
#
# Cell Num: 133
# Gene Num: 87
# Not Zero: 398
# Cluster 14 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?             Mesenchymal stem cell     7.6170    1.9
# ------------------------------------------------------------
#                    (Stem cell)         (4.0693)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 87 Group2: 1100
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                                                  go_name
#  GO:0005201        13              9  2.116300e-10  3.301428e-08  ***                              extracellular matrix structural constituent
#  GO:0030020         5              1  1.072736e-05  8.367340e-04  ***  extracellular matrix structural constituent conferring tensile strength
#  GO:0005178         7             17  1.108040e-03  4.618698e-02    *                                                         integrin binding
#  GO:0005518         6             12  1.184282e-03  4.618698e-02    *                                                         collagen binding
#  GO:0008201         6             13  1.629946e-03  5.085432e-02    -                                                          heparin binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                   go_name
#  GO:0062023        20             37  3.240627e-10  6.384035e-08  ***  collagen-containing extracellular matrix
#  GO:0005788        17             33  1.517161e-08  1.494404e-06  ***               endoplasmic reticulum lumen
#  GO:0005576        33            150  7.248463e-08  4.759824e-06  ***                      extracellular region
#  GO:0031012         9              6  1.419740e-07  6.992221e-06  ***                      extracellular matrix
#  GO:0005615        30            134  2.712581e-07  1.068757e-05  ***                       extracellular space
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                  go_name
#  GO:0030198        14             23  7.067832e-08  0.000049  ***        extracellular matrix organization
#  GO:0044267        11             23  1.241697e-05  0.004284   **       cellular protein metabolic process
#  GO:0043687        11             26  3.085604e-05  0.007097   **  post-translational protein modification
#  GO:0030449         6              7  1.479352e-04  0.020415    *      regulation of complement activation
#  GO:0001501         6              7  1.479352e-04  0.020415    *              skeletal system development
#
# Other Gene number: 1100
# ############################## Cluster 15 ##############################
#
# Cell Num: 40
# Gene Num: 91
# Not Zero: 202
# Cluster 15 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                   Astrocyte           4.1947    1.1
# ------------------------------------------------------------
#           (Natural killer T (NKT) cell)(3.7277)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 91 Group2: 1086
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                              go_name
#  GO:0008233         5              6  0.000789  0.085238   -                                                   peptidase activity
#  GO:0004579         3              1  0.001692  0.091365   -  dolichyl-diphosphooligosaccharide-protein glycotransferase activity
#  GO:0003674         6             17  0.006235  0.224464   -                                                   molecular_function
#  GO:0015037         2              1  0.016855  0.290533   -                            peptide disulfide oxidoreductase activity
#  GO:0005046         2              1  0.016855  0.290533   -                                                KDEL sequence binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                               go_name
#  GO:0005789        35             61  9.395279e-18  1.136829e-15  ***                        endoplasmic reticulum membrane
#  GO:0005783        35             79  5.379441e-15  3.254562e-13  ***                                 endoplasmic reticulum
#  GO:0005793         9              5  9.772079e-08  3.941405e-06  ***  endoplasmic reticulum-Golgi intermediate compartment
#  GO:0030134         6              3  1.266777e-05  2.668131e-04  ***            COPII-coated ER to Golgi transport vesicle
#  GO:0008250         5              1  1.403576e-05  2.668131e-04  ***                     oligosaccharyltransferase complex
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                                                go_name
#  GO:0006888        12             13  5.066120e-08  0.000023  ***              endoplasmic reticulum to Golgi vesicle-mediated transport
#  GO:0006890         8              3  1.292911e-07  0.000029  ***  retrograde vesicle-mediated transport, Golgi to endoplasmic reticulum
#  GO:0036498         7              5  7.600725e-06  0.001133   **                                IRE1-mediated unfolded protein response
#  GO:0006465         5              1  1.403576e-05  0.001568   **                                              signal peptide processing
#  GO:0007030         5              2  4.612463e-05  0.003436   **                                                     Golgi organization
#
# Other Gene number: 1086
# ############################## Cluster 16 ##############################
#
# Cell Num: 148
# Gene Num: 95
# Not Zero: 501
# Cluster 16 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?          Natural killer T (NKT) cell  6.3372    1.6
# ------------------------------------------------------------
#                     (T cell)           (3.9393)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 95 Group2: 1122
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                 go_name
#  GO:0003723        34            109  1.057830e-10  2.168551e-08  ***                             RNA binding
#  GO:0031625        11             37  7.325012e-04  4.243205e-02    *        ubiquitin protein ligase binding
#  GO:0003746         5              6  8.279425e-04  4.243205e-02    *  translation elongation factor activity
#  GO:0003743         5              6  8.279425e-04  4.243205e-02    *  translation initiation factor activity
#  GO:0036002         3              1  1.742532e-03  7.144381e-02    -                        pre-mRNA binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                               go_name
#  GO:0005634        53            365  0.000007  0.001233  **                               nucleus
#  GO:1990904         9             17  0.000076  0.007032  **             ribonucleoprotein complex
#  GO:0005654        33            205  0.000208  0.012806   *                           nucleoplasm
#  GO:0016282         3              1  0.001743  0.080592   -  eukaryotic 43S preinitiation complex
#  GO:0071013         5             10  0.004179  0.154617   -          catalytic step 2 spliceosome
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                   go_name
#  GO:0000398        11             17  0.000003  0.001860  **                            mRNA splicing, via spliceosome
#  GO:0000381         6              3  0.000013  0.004778  **  regulation of alternative mRNA splicing, via spliceosome
#  GO:0006413         7              7  0.000031  0.007340  **                                  translational initiation
#  GO:0006397         6              7  0.000212  0.030296   *                                           mRNA processing
#  GO:0043488         7             11  0.000222  0.030296   *                              regulation of mRNA stability
#
# Other Gene number: 1122
# ############################## Cluster 17 ##############################
#
# Cell Num: 182
# Gene Num: 93
# Not Zero: 597
# Cluster 17 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                Endothelial cell       9.5561    1.7
# ------------------------------------------------------------
#              (Mesenchymal stem cell)   (5.7366)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 93 Group2: 1089
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                       go_name
#  GO:0008565         3              3  0.007926  0.351025   -                                  protein transporter activity
#  GO:0015026         5             13  0.010189  0.351025   -                                           coreceptor activity
#  GO:0043236         3              4  0.013084  0.351025   -                                               laminin binding
#  GO:0005001         2              1  0.017442  0.351025   -  transmembrane receptor protein tyrosine phosphatase activity
#  GO:0034713         2              1  0.017442  0.351025   -       type I transforming growth factor beta receptor binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                   go_name
#  GO:0005925        18             61  0.000014  0.002315  **                            focal adhesion
#  GO:0005886        50            346  0.000022  0.002315  **                           plasma membrane
#  GO:0043235         8             17  0.000386  0.025888   *                          receptor complex
#  GO:0005913         7             13  0.000495  0.025888   *               cell-cell adherens junction
#  GO:0062023        12             43  0.000713  0.029824   *  collagen-containing extracellular matrix
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                                          go_name
#  GO:0001525        17             25  2.060286e-09  0.000001  ***                                                     angiogenesis
#  GO:0007156         6              4  3.294423e-05  0.011975    *  homophilic cell adhesion via plasma membrane adhesion molecules
#  GO:0030198        11             27  8.081020e-05  0.019583    *                                extracellular matrix organization
#  GO:0001570         5              4  2.656809e-04  0.048288    *                                                   vasculogenesis
#  GO:0031623         6              8  3.628959e-04  0.052765    -                                         receptor internalization
#
# Other Gene number: 1089
# ############################## Cluster 18 ##############################
#
# Cell Num: 98
# Gene Num: 93
# Not Zero: 332
# Cluster 18 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                   Stem cell           6.7989    1.8
# ------------------------------------------------------------
#                 (Progenitor cell)      (3.8790)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 93 Group2: 1103
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                 go_name
#  GO:0003723        20            114  0.002019  0.318916   -                             RNA binding
#  GO:0097110         5              9  0.002912  0.318916   -                scaffold protein binding
#  GO:0003743         4              7  0.007401  0.396252   -  translation initiation factor activity
#  GO:0044877         6             19  0.009923  0.396252   -      protein-containing complex binding
#  GO:0005198         6             20  0.012106  0.396252   -            structural molecule activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                         go_name
#  GO:0005882         7             10  0.000141  0.015306   *                           intermediate filament
#  GO:0016327         4              1  0.000162  0.015306   *                    apicolateral plasma membrane
#  GO:0070062        42            296  0.000218  0.015306   *                           extracellular exosome
#  GO:0005829        50            394  0.000496  0.026171   *                                         cytosol
#  GO:0019773         3              1  0.001722  0.072658   -  proteasome core complex, alpha-subunit complex
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                       go_name
#  GO:0070268         7             18  0.002066  0.421766   -                 cornification
#  GO:0007219         4              8  0.010447  0.421766   -       Notch signaling pathway
#  GO:0030216         4              9  0.014205  0.421766   -  keratinocyte differentiation
#  GO:0006413         4              9  0.014205  0.421766   -      translational initiation
#  GO:0045214         2              1  0.017047  0.421766   -        sarcomere organization
#
# Other Gene number: 1103
# ############################## Cluster 19 ##############################
#
# Cell Num: 125
# Gene Num: 94
# Not Zero: 428
# Cluster 19 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good                  B cell            8.9245    2.4
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 94 Group2: 1109
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                                go_name
#  GO:0000978        11             51  0.006536  0.475804   -      RNA polymerase II proximal promoter sequence-specific DNA binding
#  GO:0003677        12             64  0.011775  0.475804   -                                                            DNA binding
#  GO:0000981        13             73  0.012645  0.475804   -  DNA-binding transcription factor activity, RNA polymerase II-specific
#  GO:0070888         3              5  0.019392  0.475804   -                                                          E-box binding
#  GO:0043425         2              2  0.032674  0.475804   -                                      bHLH transcription factor binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                          go_name
#  GO:0048471        14             79  0.010025  0.561359   -  perinuclear region of cytoplasm
#  GO:0035578         4             10  0.019039  0.561359   -          azurophil granule lumen
#  GO:0005783        15             99  0.025653  0.561359   -            endoplasmic reticulum
#  GO:0005788         8             41  0.031920  0.561359   -      endoplasmic reticulum lumen
#  GO:0005789        13             84  0.032553  0.561359   -   endoplasmic reticulum membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                            go_name
#  GO:0120162         5             10  0.004194  0.400321   -  positive regulation of cold-induced thermogenesis
#  GO:0071333         4              7  0.007533  0.400321   -              cellular response to glucose stimulus
#  GO:0048146         4              7  0.007533  0.400321   -    positive regulation of fibroblast proliferation
#  GO:0050885         3              3  0.007775  0.400321   -          neuromuscular process controlling balance
#  GO:0032148         3              3  0.007775  0.400321   -            activation of protein kinase B activity
#
# Other Gene number: 1109
# ############################## Cluster 2 ##############################
#
# Cell Num: 106
# Gene Num: 44
# Not Zero: 278
# Cluster 2 Gene number: 46
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                Microglial cell        6.0544    1.2
# ------------------------------------------------------------
#                     (T cell)           (4.8447)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 44 Group2: 1139
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                go_name
#  GO:0043548         3              5  0.002362  0.134133   -  phosphatidylinositol 3-kinase binding
#  GO:0042288         3              6  0.003451  0.134133   -            MHC class I protein binding
#  GO:0008009         3              8  0.006433  0.134133   -                     chemokine activity
#  GO:0004252         4             18  0.007469  0.134133   -     serine-type endopeptidase activity
#  GO:0031726         2              2  0.007738  0.134133   -        CCR1 chemokine receptor binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                           go_name
#  GO:0005576        16            168  0.000465  0.033940   *              extracellular region
#  GO:0042101         3              7  0.004803  0.175306   -           T cell receptor complex
#  GO:0009897         8             76  0.009913  0.241226   -  external side of plasma membrane
#  GO:0001772         3             12  0.015981  0.291659   -             immunological synapse
#  GO:0042612         2              5  0.025217  0.322557   -       MHC class I protein complex
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                           go_name
#  GO:0006955        11             69  0.000084  0.031647   *                                                   immune response
#  GO:0050776         8             42  0.000318  0.059977   -                                     regulation of immune response
#  GO:0002250         6             28  0.001150  0.144491   -                                          adaptive immune response
#  GO:0045954         3              5  0.002362  0.178103   -  positive regulation of natural killer cell mediated cytotoxicity
#  GO:0019835         3              5  0.002362  0.178103   -                                                         cytolysis
#
# Other Gene number: 1139
# ############################## Cluster 20 ##############################
#
# Cell Num: 97
# Gene Num: 55
# Not Zero: 265
# Cluster 20 Gene number: 62
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good           Natural killer cell      8.5605    2.5
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 55 Group2: 1126
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                    go_name
#  GO:0004888         7             23  0.000286  0.027400   *  transmembrane signaling receptor activity
#  GO:1990405         3              2  0.000896  0.027400   *                    protein antigen binding
#  GO:0023024         3              2  0.000896  0.027400   *        MHC class I protein complex binding
#  GO:0030246         6             21  0.001075  0.027400   *                       carbohydrate binding
#  GO:0017091         2              2  0.012033  0.154205   -                    AU-rich element binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                     go_name
#  GO:0043235         4             21  0.025676  0.637071   -                                            receptor complex
#  GO:0031234         2              8  0.075399  0.637071   -  extrinsic component of cytoplasmic side of plasma membrane
#  GO:0016021        16            228  0.082694  0.637071   -                              integral component of membrane
#  GO:0000178         1              1  0.091010  0.637071   -                                     exosome (RNase complex)
#  GO:0098745         1              1  0.091010  0.637071   -                                           Dcp1-Dcp2 complex
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                     go_name
#  GO:0050776         8             40  0.001167  0.298577   -                               regulation of immune response
#  GO:0006968         5             16  0.002097  0.298577   -                                   cellular defense response
#  GO:0042119         2              1  0.006202  0.298577   -                                       neutrophil activation
#  GO:2000556         2              1  0.006202  0.298577   -  positive regulation of T-helper 1 cell cytokine production
#  GO:0002228         2              1  0.006202  0.298577   -                       natural killer cell mediated immunity
#
# Other Gene number: 1126
# ############################## Cluster 21 ##############################
#
# Cell Num: 118
# Gene Num: 87
# Not Zero: 331
# Cluster 21 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                   Mast cell           7.3203    1.6
# ------------------------------------------------------------
#             (Hematopoietic stem cell)  (4.6294)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 87 Group2: 1093
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                   go_name
#  GO:0046872        15             80  0.002651  0.264554   -                         metal ion binding
#  GO:0005524        13             67  0.004047  0.264554   -                               ATP binding
#  GO:0004674         5             11  0.004434  0.264554   -  protein serine/threonine kinase activity
#  GO:0017049         2              1  0.015358  0.363318   -                           GTP-Rho binding
#  GO:0005506         2              1  0.015358  0.363318   -                          iron ion binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                 go_name
#  GO:0031088         2              1  0.015358  0.588465   -                         platelet dense granule membrane
#  GO:0044233         2              1  0.015358  0.588465   -  mitochondria-associated endoplasmic reticulum membrane
#  GO:0008021         3              5  0.016535  0.588465   -                                        synaptic vesicle
#  GO:0031965         5             17  0.018774  0.588465   -                                        nuclear membrane
#  GO:0005635         5             17  0.018774  0.588465   -                                        nuclear envelope
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                      go_name
#  GO:0042759         3              1  0.001469  0.402619   -                   long-chain fatty acid biosynthetic process
#  GO:0051968         3              1  0.001469  0.402619   -  positive regulation of synaptic transmission, glutamatergic
#  GO:0019371         3              2  0.003477  0.402619   -                                       cyclooxygenase pathway
#  GO:0019370         3              3  0.006584  0.402619   -                             leukotriene biosynthetic process
#  GO:0006468         7             26  0.008183  0.402619   -                                      protein phosphorylation
#
# Other Gene number: 1093
# ############################## Cluster 3 ##############################
#
# Cell Num: 81
# Gene Num: 24
# Not Zero: 169
# Cluster 3 Gene number: 32
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                     T cell            4.8948    1.3
# ------------------------------------------------------------
#               (Natural killer cell)    (3.9133)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 24 Group2: 1148
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                    go_name
#  GO:0004888         4             26  0.002600  0.124302   -  transmembrane signaling receptor activity
#  GO:0017124         3             13  0.003551  0.124302   -                         SH3 domain binding
#  GO:0004252         3             19  0.009006  0.166985   -         serine-type endopeptidase activity
#  GO:0008009         2              9  0.019756  0.166985   -                         chemokine activity
#  GO:0031698         1              1  0.040553  0.166985   -         beta-2 adrenergic receptor binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                            go_name
#  GO:0001772         3             12  0.002925  0.106588   -              immunological synapse
#  GO:0009897         6             76  0.004737  0.106588   -   external side of plasma membrane
#  GO:0005886        13            382  0.029775  0.304151   -                    plasma membrane
#  GO:0045334         1              1  0.040553  0.304151   -  clathrin-coated endocytic vesicle
#  GO:0032590         1              1  0.040553  0.304151   -                  dendrite membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                          go_name
#  GO:0019835         3              6  0.000586  0.124746   -                                        cytolysis
#  GO:0002544         2              1  0.001192  0.126296   -                    chronic inflammatory response
#  GO:0070234         2              2  0.002353  0.126296   -  positive regulation of T cell apoptotic process
#  GO:0070098         3             11  0.002372  0.126296   -             chemokine-mediated signaling pathway
#  GO:0008626         2              3  0.003873  0.126673   -    granzyme-mediated apoptotic signaling pathway
#
# Other Gene number: 1148
# ############################## Cluster 4 ##############################
#
# Cell Num: 106
# Gene Num: 87
# Not Zero: 411
# Cluster 4 Gene number: 95
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good                  B cell            10.0021   8.7
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 87 Group2: 1094
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                     go_name
#  GO:0032395         5              3  0.000091  0.012389   *              MHC class II receptor activity
#  GO:0023026         6             11  0.000861  0.055139   -        MHC class II protein complex binding
#  GO:0042605         6             12  0.001216  0.055139   -                     peptide antigen binding
#  GO:0005085         3              6  0.023443  0.616548   -  guanyl-nucleotide exchange factor activity
#  GO:0035091         2              2  0.029200  0.616548   -                phosphatidylinositol binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                     go_name
#  GO:0042613         9              7  3.187256e-07  0.000043  ***                MHC class II protein complex
#  GO:0030658         7              6  1.110495e-05  0.000755  ***                  transport vesicle membrane
#  GO:0030669         7              7  2.088795e-05  0.000947  ***  clathrin-coated endocytic vesicle membrane
#  GO:0005765        11             28  5.605038e-05  0.001906   **                          lysosomal membrane
#  GO:0032588         7             10  9.847567e-05  0.002679   **                trans-Golgi network membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                                                            go_name
#  GO:0050853         9              6  1.483330e-07  0.000073  ***                                                  B cell receptor signaling pathway
#  GO:0006959         9              9  1.197055e-06  0.000295  ***                                                            humoral immune response
#  GO:0042113         6              2  3.364376e-06  0.000553  ***                                                                  B cell activation
#  GO:0019886         9             13  9.563572e-06  0.001179   **  antigen processing and presentation of exogenous peptide antigen via MHC class II
#  GO:0042100         5              5  3.638501e-04  0.035876    *                                                               B cell proliferation
#
# Other Gene number: 1094
# ############################## Cluster 5 ##############################
#
# !WARNING3:Zero marker sets found, type:marker
# !WARNING3:Change the threshold or tissue name and try again?
# !WARNING3:EnsemblID or GeneID,try '-E' command?
# Cluster 5 Gene number: 0
# None
# !WARNING(go processing):Zero gene sets found for the cluster 5
# !WARNING(go processing):Change the threshold and try again?
# Other Gene number: 1155
# ############################## Cluster 6 ##############################
#
# Cell Num: 127
# Gene Num: 96
# Not Zero: 510
# Cluster 6 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good                  B cell            9.1003    2.2
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 96 Group2: 1087
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                               go_name
#  GO:0042605         6             13  0.002784  0.469982   -               peptide antigen binding
#  GO:0005543         3              3  0.008654  0.469982   -                  phospholipid binding
#  GO:0030145         3              3  0.008654  0.469982   -                 manganese ion binding
#  GO:0023026         5             13  0.011603  0.469982   -  MHC class II protein complex binding
#  GO:0001664         3              4  0.014259  0.469982   -    G protein-coupled receptor binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                       go_name
#  GO:0005765        11             29  0.000181  0.010539   *            lysosomal membrane
#  GO:0042613         7             10  0.000185  0.010539   *  MHC class II protein complex
#  GO:1904724         6              7  0.000264  0.010539   *        tertiary granule lumen
#  GO:0032588         7             11  0.000283  0.010539   *  trans-Golgi network membrane
#  GO:0030658         6              8  0.000431  0.012851   *    transport vesicle membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                                            go_name
#  GO:0043312        22             75  0.000002  0.001743  **                                                           neutrophil degranulation
#  GO:0019886         9             15  0.000050  0.017593   *  antigen processing and presentation of exogenous peptide antigen via MHC class II
#  GO:0006954        12             47  0.001843  0.277042   -                                                              inflammatory response
#  GO:0030225         3              1  0.001954  0.277042   -                                                         macrophage differentiation
#  GO:0002430         3              1  0.001954  0.277042   -                                     complement receptor mediated signaling pathway
#
# Other Gene number: 1087
# ############################## Cluster 7 ##############################
#
# Cell Num: 156
# Gene Num: 95
# Not Zero: 619
# Cluster 7 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                     T cell            7.5330    1.3
# ------------------------------------------------------------
#               (Natural killer cell)    (5.6587)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 95 Group2: 1121
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                    go_name
#  GO:0042608         4              2  0.000465  0.094952   -                    T cell receptor binding
#  GO:0042605         6             13  0.002290  0.221036   -                    peptide antigen binding
#  GO:0042288         4              5  0.003251  0.221036   -                MHC class I protein binding
#  GO:0003785         3              3  0.007773  0.385761   -                      actin monomer binding
#  GO:0004888         7             25  0.009455  0.385761   -  transmembrane signaling receptor activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value  sig                           go_name
#  GO:0005886        54            368  0.000004  0.000589  ***                   plasma membrane
#  GO:0016020        33            194  0.000077  0.005088   **                          membrane
#  GO:0009897        18             73  0.000104  0.005088   **  external side of plasma membrane
#  GO:0042101         6              6  0.000123  0.005088   **           T cell receptor complex
#  GO:0030670         7             14  0.000669  0.022203    *       phagocytic vesicle membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                  go_name
#  GO:0050776        18             41  1.140362e-07  0.000083  ***            regulation of immune response
#  GO:0007166        15             43  1.511970e-05  0.005526   **  cell surface receptor signaling pathway
#  GO:0042110         9             15  3.655430e-05  0.008907   **                        T cell activation
#  GO:0002250        10             28  3.972904e-04  0.058852    -                 adaptive immune response
#  GO:0006955        16             68  4.259004e-04  0.058852    -                          immune response
#
# Other Gene number: 1121
# ############################## Cluster 8 ##############################
#
# Cell Num: 134
# Gene Num: 93
# Not Zero: 371
# Cluster 8 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                   Basal cell          6.1827    1.4
# ------------------------------------------------------------
#               (Embryonic stem cell)    (4.4368)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 93 Group2: 1099
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                  go_name
#  GO:0008106         5              1  0.000015  0.002236  **   alcohol dehydrogenase (NADP+) activity
#  GO:0004032         4              1  0.000164  0.012462   *  alditol:NADP+ 1-oxidoreductase activity
#  GO:0016491         5              4  0.000255  0.012934   *                  oxidoreductase activity
#  GO:0005198         8             20  0.000859  0.032655   *             structural molecule activity
#  GO:0004033         3              1  0.001739  0.052860   -      aldo-keto reductase (NADP) activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                go_name
#  GO:0001533         5              8  0.002024  0.196852   -                     cornified envelope
#  GO:0005882         6             14  0.003039  0.196852   -                  intermediate filament
#  GO:0046658         3              2  0.004101  0.196852   -  anchored component of plasma membrane
#  GO:0030057         4              7  0.007489  0.217456   -                              desmosome
#  GO:0005615        21            140  0.008741  0.217456   -                    extracellular space
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                       go_name
#  GO:0001523         8              2  4.068159e-08  0.000026  ***    retinoid metabolic process
#  GO:0006805         7              7  3.083154e-05  0.008948   **  xenobiotic metabolic process
#  GO:0070268        10             20  4.214343e-05  0.008948   **                 cornification
#  GO:0008202         4              1  1.639709e-04  0.026112    *     steroid metabolic process
#  GO:0008544         6              9  5.414696e-04  0.068983    -         epidermis development
#
# Other Gene number: 1099
# ############################## Cluster 9 ##############################
#
# Cell Num: 100
# Gene Num: 73
# Not Zero: 324
# Cluster 9 Gene number: 80
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?          Natural killer T (NKT) cell  4.6207    1.0
# ------------------------------------------------------------
#                     (T cell)           (4.5446)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 73 Group2: 1121
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                           go_name
#  GO:0051082        15             15  1.107050e-11  2.003760e-09  ***          unfolded protein binding
#  GO:0051087        10             13  2.384511e-07  2.157982e-05  ***                 chaperone binding
#  GO:0005524        18             65  6.056179e-07  3.653894e-05  ***                       ATP binding
#  GO:0031625        13             34  1.534542e-06  6.943803e-05  ***  ubiquitin protein ligase binding
#  GO:0042623         6              3  3.101374e-06  1.122697e-04  ***          ATPase activity, coupled
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                     go_name
#  GO:0008180         4              3  0.000392  0.024539   *            COP9 signalosome
#  GO:0032991        13             65  0.000518  0.024539   *  protein-containing complex
#  GO:0043209         8             25  0.000535  0.024539   *               myelin sheath
#  GO:0101031         3              1  0.000840  0.024539   *           chaperone complex
#  GO:0016234         3              1  0.000840  0.024539   *              inclusion body
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                         go_name
#  GO:0006986        13              9  1.840716e-11  1.222235e-08  ***                    response to unfolded protein
#  GO:1900034         9              8  1.200890e-07  3.986956e-05  ***         regulation of cellular response to heat
#  GO:0051085         7              4  6.530521e-07  1.445422e-04  ***  chaperone cofactor-dependent protein refolding
#  GO:0051131         6              3  3.101374e-06  5.148280e-04  ***     chaperone-mediated protein complex assembly
#  GO:0042026         7              7  5.848283e-06  7.766520e-04  ***                               protein refolding
#
# Other Gene number: 1121
# ################################################################################
#
# #Cluster Type Celltype Score Times
# ['0', '?', 'T cell|Natural killer T (NKT) cell', '5.712727202777739|4.892631728160635', 1.1676184761458464]
# ['1', '?', 'Microglial cell|Hematopoietic stem cell', '4.9092118585182565|3.365902893623283', 1.4585126231118486]
# ['10', '?', 'Regulatory T (Treg) cell|T cell', '8.401687869071866|7.3575586977869225', 1.1419124487038081]
# ['11', 'Good', 'Natural killer T (NKT) cell', 1.7884974306693864, 4.105908458170588]
# ['12', 'Good', 'Basal cell', 8.933274339696899, 2.6127750261093983]
# ['13', 'Good', 'Natural killer T (NKT) cell', 6.342198127983272, 2.1404190021875396]
# ['14', '?', 'Mesenchymal stem cell|Stem cell', '7.616968367451205|4.069285794842815', 1.8718194669699837]
# ['15', '?', 'Astrocyte|Natural killer T (NKT) cell', '4.194690400640201|3.72774143481479', 1.1252632388782111]
# ['16', '?', 'Natural killer T (NKT) cell|T cell', '6.337216375527772|3.93928418346237', 1.6087228238399847]
# ['17', '?', 'Endothelial cell|Mesenchymal stem cell', '9.556139923846047|5.736570753736374', 1.665827954378823]
# ['18', '?', 'Stem cell|Progenitor cell', '6.798889229477258|3.879032312768262', 1.752728175812809]
# ['19', 'Good', 'B cell', 8.924533246782545, 2.4278326355814506]
# ['2', '?', 'Microglial cell|T cell', '6.054435799568078|4.844725563158944', 1.249696338964628]
# ['20', 'Good', 'Natural killer cell', 8.560466968658199, 2.524603191469]
# ['21', '?', 'Mast cell|Hematopoietic stem cell', '7.320327142744506|4.6293989466416905', 1.5812694535766674]
# ['3', '?', 'T cell|Natural killer cell', '4.89477522204045|3.913269972025537', 1.2508146018627175]
# ['4', 'Good', 'B cell', 10.002051239667471, 8.719888378272737]
# ['5', 'N', '-', '-', '-']
# ['6', 'Good', 'B cell', 9.100297135359462, 2.177966017963127]
# ['7', '?', 'T cell|Natural killer cell', '7.532985213457449|5.6587393670026875', 1.3312126120145924]
# ['8', '?', 'Basal cell|Embryonic stem cell', '6.182744173606671|4.436823162116818', 1.39350700888806]
# ['9', '?', 'Natural killer T (NKT) cell|T cell', '4.620663226024971|4.54455832942258', 1.0167463790946787]
