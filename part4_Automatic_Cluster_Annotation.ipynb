# %% [markdown]
# We use SCSA to help annotate the clusters. SCSA annotation is based on a few manually curated database. Instructions can be found https://github.com/bioinfo-ibms-pumc/SCSA.

# %%
cd /SCSA

# %%
python3 SCSA.py -d whole.db -i /scratch/umap_cluster.csv -s scanpy -E -f1.5 -p 0.01 -o /scratch/umap_annotation_result -m txt
# Out:
# DB load: 47347 3 3 48257 37440
# Namespace(Gensymbol=True, MarkerDB=None, celltype='normal', cluster='all', db='whole.db', foldchange=1.5, input='/scratch/umap_cluster.csv', list_tissue=False, noprint=False, norefdb=False, outfmt='txt', output='/scratch/umap_annotation_result', pvalue=0.01, source='scanpy', species='Human', target='cellmarker', tissue='All', weight=100.0)
# DB load: 47347 3 3 48257 37440
# load markers: 45409
# ############################## Cluster 0 ##############################
#
# Cell Num: 110
# Gene Num: 58
# Not Zero: 397
# Cluster 0 Gene number: 66
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                     T cell            6.4167    1.3
# ------------------------------------------------------------
#               (Natural killer cell)    (4.8930)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 58 Group2: 1101
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                    go_name
#  GO:0004888         8             22  0.000060  0.006748  **  transmembrane signaling receptor activity
#  GO:0030246         6             22  0.001930  0.109055   -                       carbohydrate binding
#  GO:0017124         4             13  0.008249  0.306428   -                         SH3 domain binding
#  GO:0023024         2              3  0.022332  0.306428   -        MHC class I protein complex binding
#  GO:1990405         2              3  0.022332  0.306428   -                    protein antigen binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                go_name
#  GO:0009897        14             66  0.000016  0.001216  **       external side of plasma membrane
#  GO:0005886        34            356  0.000056  0.002165  **                        plasma membrane
#  GO:0005887        16            107  0.000166  0.004321  **  integral component of plasma membrane
#  GO:0042101         4              9  0.002882  0.056194   -                T cell receptor complex
#  GO:0042105         3              4  0.003610  0.056313   -     alpha-beta T cell receptor complex
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                  go_name
#  GO:0050776        13             42  9.229292e-07  0.000349  ***            regulation of immune response
#  GO:0007166        11             39  1.557073e-05  0.002943   **  cell surface receptor signaling pathway
#  GO:0006955        12             65  2.330857e-04  0.029369    *                          immune response
#  GO:0019835         4              5  5.909082e-04  0.047589    *                                cytolysis
#  GO:0042110         6             17  6.294795e-04  0.047589    *                        T cell activation
#
# Other Gene number: 1101
# ############################## Cluster 1 ##############################
#
# Cell Num: 25
# Gene Num: 2
# Not Zero: 28
# Cluster 1 Gene number: 4
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                 T helper cell         2.3419    1.0
# ------------------------------------------------------------
#           (Natural killer T (NKT) cell)(2.3419)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 2 Group2: 1131
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                             go_name
#  GO:0004917         1              2  0.005291  0.026373   *     interleukin-7 receptor activity
#  GO:0003823         1              6  0.012324  0.026373   *                     antigen binding
#  GO:0004896         1              7  0.014078  0.026373   *          cytokine receptor activity
#  GO:0008236         1              9  0.017582  0.026373   *      serine-type peptidase activity
#  GO:0004252         1             18  0.033273  0.039927   *  serine-type endopeptidase activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                           go_name
#  GO:0030665         1              6  0.012324  0.058676   -  clathrin-coated vesicle membrane
#  GO:0005576         2            172  0.023470  0.058676   -              extracellular region
#  GO:0009897         1             71  0.123110  0.205184   -  external side of plasma membrane
#  GO:0016021         1            224  0.357879  0.447349   -    integral component of membrane
#  GO:0005886         1            373  0.551425  0.551425   -                   plasma membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                     go_name
#  GO:0000018         1              1  0.003529  0.019579   *                             regulation of DNA recombination
#  GO:1904894         1              1  0.003529  0.019579   *  positive regulation of receptor signaling pathway via STAT
#  GO:0001915         1              2  0.005291  0.019579   *         negative regulation of T cell mediated cytotoxicity
#  GO:0033089         1              2  0.005291  0.019579   *     positive regulation of T cell differentiation in thymus
#  GO:0048872         1              3  0.007052  0.019579   *                              homeostasis of number of cells
#
# Other Gene number: 1131
# ############################## Cluster 10 ##############################
#
# Cell Num: 155
# Gene Num: 98
# Not Zero: 589
# Cluster 10 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                     T cell            7.6552    1.3
# ------------------------------------------------------------
#           (Natural killer T (NKT) cell)(5.9760)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 98 Group2: 1095
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                      go_name
#  GO:0003779         9             19  0.000220  0.039734   *                actin binding
#  GO:0042605         6             12  0.002174  0.118108   -      peptide antigen binding
#  GO:0042608         4              4  0.002321  0.118108   -      T cell receptor binding
#  GO:0051015         7             18  0.002855  0.118108   -       actin filament binding
#  GO:0042288         4              5  0.003915  0.118108   -  MHC class I protein binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                      go_name
#  GO:0016020        34            183  0.000033  0.006337  **                     membrane
#  GO:0030670         8             14  0.000191  0.012760   *  phagocytic vesicle membrane
#  GO:0005885         4              1  0.000201  0.012760   *       Arp2/3 protein complex
#  GO:0005925        17             70  0.000369  0.017543   *               focal adhesion
#  GO:0005886        49            360  0.000594  0.019521   *              plasma membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                       go_name
#  GO:0050776        15             45  0.000044  0.034384   *                                 regulation of immune response
#  GO:0038096         8             12  0.000086  0.034384   *  Fc-gamma receptor signaling pathway involved in phagocytosis
#  GO:0034314         4              1  0.000201  0.053524   -                      Arp2/3 complex-mediated actin nucleation
#  GO:0061024         9             21  0.000395  0.072135   -                                         membrane organization
#  GO:0048013         7             12  0.000453  0.072135   -                             ephrin receptor signaling pathway
#
# Other Gene number: 1095
# ############################## Cluster 11 ##############################
#
# Cell Num: 166
# Gene Num: 97
# Not Zero: 535
# Cluster 11 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                     T cell            7.2381    1.4
# ------------------------------------------------------------
#           (Natural killer T (NKT) cell)(5.2416)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 97 Group2: 1079
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                  go_name
#  GO:0019901        15             52  0.000182  0.037882   *                                   protein kinase binding
#  GO:0005515        82            737  0.000361  0.037882   *                                          protein binding
#  GO:0004842         5              8  0.002603  0.159066   -                   ubiquitin-protein transferase activity
#  GO:0004672         5              9  0.003787  0.159066   -                                  protein kinase activity
#  GO:0046934         5              9  0.003787  0.159066   -  phosphatidylinositol-4,5-bisphosphate 3-kinase activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value  q-value sig                           go_name
#  GO:0042612         4              5  0.003973  0.18395   -       MHC class I protein complex
#  GO:0009897        14             66  0.004064  0.18395   -  external side of plasma membrane
#  GO:1990904         6             15  0.005286  0.18395   -         ribonucleoprotein complex
#  GO:0001772         5             10  0.005314  0.18395   -             immunological synapse
#  GO:0005634        45            355  0.005677  0.18395   -                           nucleus
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                              go_name
#  GO:0000209         6              5  0.000089  0.050160   -                           protein polyubiquitination
#  GO:0006468        11             27  0.000126  0.050160   -                              protein phosphorylation
#  GO:0050852        10             26  0.000383  0.101407   -                    T cell receptor signaling pathway
#  GO:0050690         5              6  0.001069  0.212397   -     regulation of defense response to virus by virus
#  GO:0045893        10             32  0.001452  0.230940   -  positive regulation of transcription, DNA-templated
#
# Other Gene number: 1079
# ############################## Cluster 12 ##############################
#
# Cell Num: 102
# Gene Num: 82
# Not Zero: 342
# Cluster 12 Gene number: 88
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?          Natural killer T (NKT) cell  5.0060    1.3
# ------------------------------------------------------------
#              (T helper1 (Th1) cell)    (3.9353)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 82 Group2: 1085
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                     go_name
#  GO:0051082        17             15  1.161213e-12  2.264366e-10  ***    unfolded protein binding
#  GO:0051087        11             13  1.257443e-07  1.226007e-05  ***           chaperone binding
#  GO:0031072         8              6  9.050124e-07  5.882581e-05  ***  heat shock protein binding
#  GO:0042623         6              2  2.522210e-06  1.167944e-04  ***    ATPase activity, coupled
#  GO:0005524        19             69  2.994727e-06  1.167944e-04  ***                 ATP binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                     go_name
#  GO:0005634        44            358  0.000166  0.022542   *                     nucleus
#  GO:0032991        14             59  0.000297  0.022542   *  protein-containing complex
#  GO:0005737        41            336  0.000423  0.022542   *                   cytoplasm
#  GO:0043209         8             23  0.000881  0.025559   *               myelin sheath
#  GO:0101031         3              1  0.001273  0.025559   *           chaperone complex
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                         go_name
#  GO:0006986        13              7  2.072149e-11  1.523029e-08  ***                    response to unfolded protein
#  GO:1900034        10              6  9.722529e-09  3.573029e-06  ***         regulation of cellular response to heat
#  GO:0051085         7              4  1.730320e-06  4.239283e-04  ***  chaperone cofactor-dependent protein refolding
#  GO:0051131         6              3  7.142498e-06  1.059498e-03   **     chaperone-mediated protein complex assembly
#  GO:0042026         7              6  8.009331e-06  1.059498e-03   **                               protein refolding
#
# Other Gene number: 1085
# ############################## Cluster 13 ##############################
#
# !WARNING3:Zero marker sets found, type:marker
# !WARNING3:Change the threshold or tissue name and try again?
# !WARNING3:EnsemblID or GeneID,try '-E' command?
# Cluster 13 Gene number: 1
# None
# Go Enrichment analysis: Group1: 1 Group2: 1131
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Other Gene number: 1131
# ############################## Cluster 14 ##############################
#
# Cell Num: 47
# Gene Num: 94
# Not Zero: 267
# Cluster 14 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good       Natural killer T (NKT) cell  5.2657    3.1
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 94 Group2: 1061
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                      go_name
#  GO:0003723        29             99  3.611747e-08  0.000006  ***                  RNA binding
#  GO:0005515        82            721  2.753790e-05  0.002299   **              protein binding
#  GO:0003697         7              8  7.126898e-05  0.003967   **  single-stranded DNA binding
#  GO:0003682         9             18  1.471180e-04  0.006142   **            chromatin binding
#  GO:0031492         5              4  3.121206e-04  0.008687   **      nucleosomal DNA binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                           go_name
#  GO:0005634        70            331  2.392190e-16  4.449474e-14  ***                           nucleus
#  GO:0005654        48            178  6.238448e-13  5.801756e-11  ***                       nucleoplasm
#  GO:0071013         9              3  1.946750e-08  1.206985e-06  ***      catalytic step 2 spliceosome
#  GO:0000777         7              1  1.431148e-07  5.323872e-06  ***  condensed chromosome kinetochore
#  GO:0000793         7              1  1.431148e-07  5.323872e-06  ***              condensed chromosome
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                                 go_name
#  GO:0051301        20              6  3.402951e-18  2.021353e-15  ***                                           cell division
#  GO:0000398        12             12  5.098744e-08  1.514327e-05  ***                          mRNA splicing, via spliceosome
#  GO:0000278         8              7  5.766701e-06  1.141807e-03   **                                      mitotic cell cycle
#  GO:0031145         6              3  1.714382e-05  2.155522e-03   **  anaphase-promoting complex-dependent catabolic process
#  GO:0007059         5              1  1.814413e-05  2.155522e-03   **                                  chromosome segregation
#
# Other Gene number: 1061
# ############################## Cluster 15 ##############################
#
# Cell Num: 131
# Gene Num: 89
# Not Zero: 399
# Cluster 15 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?             Mesenchymal stem cell     7.5465    1.9
# ------------------------------------------------------------
#                    (Stem cell)         (4.0270)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 89 Group2: 1080
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                                                  go_name
#  GO:0005201        13              9  3.465798e-10  5.441302e-08  ***                              extracellular matrix structural constituent
#  GO:0030020         5              1  1.297694e-05  1.018690e-03   **  extracellular matrix structural constituent conferring tensile strength
#  GO:0005518         6             12  1.449656e-03  7.586533e-02    -                                                         collagen binding
#  GO:0005178         7             19  2.332358e-03  8.386895e-02    -                                                         integrin binding
#  GO:0008201         6             14  2.670986e-03  8.386895e-02    -                                                          heparin binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                   go_name
#  GO:0062023        20             38  9.569654e-10  1.818234e-07  ***  collagen-containing extracellular matrix
#  GO:0005788        17             29  6.287370e-09  5.973001e-07  ***               endoplasmic reticulum lumen
#  GO:0031012         9              5  8.478737e-08  5.369867e-06  ***                      extracellular matrix
#  GO:0005576        33            150  2.031147e-07  9.647950e-06  ***                      extracellular region
#  GO:0005615        30            139  1.376071e-06  5.229070e-05  ***                       extracellular space
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                  go_name
#  GO:0030198        14             24  1.727719e-07  0.000120  ***        extracellular matrix organization
#  GO:0043687        12             25  6.962609e-06  0.002138   **  post-translational protein modification
#  GO:0044267        11             21  9.243414e-06  0.002138   **       cellular protein metabolic process
#  GO:0030449         6              8  3.013324e-04  0.052281    -      regulation of complement activation
#  GO:0030199         4              2  4.195337e-04  0.058231    -             collagen fibril organization
#
# Other Gene number: 1080
# ############################## Cluster 16 ##############################
#
# Cell Num: 97
# Gene Num: 86
# Not Zero: 286
# Cluster 16 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good                Basal cell          8.8675    2.6
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 86 Group2: 1092
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                          go_name
#  GO:0005200         9             19  0.000085  0.015064   *           structural constituent of cytoskeleton
#  GO:0045296        12             42  0.000289  0.022051   *                                 cadherin binding
#  GO:0098641         6              9  0.000374  0.022051   *  cadherin binding involved in cell-cell adhesion
#  GO:0042802        17             99  0.002777  0.122868   -                        identical protein binding
#  GO:0005544         4              7  0.005883  0.208263   -           calcium-dependent phospholipid binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value  sig                      go_name
#  GO:0070062        46            304  0.000001  0.000274  ***        extracellular exosome
#  GO:0030057         7              5  0.000005  0.000494  ***                    desmosome
#  GO:0005882         8             13  0.000054  0.003497   **        intermediate filament
#  GO:0001533         6              9  0.000374  0.018033    *           cornified envelope
#  GO:0005913         7             15  0.000601  0.023192    *  cell-cell adherens junction
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                go_name
#  GO:0031424        13             15  1.045856e-08  0.000007  ***         keratinization
#  GO:0070268        13             17  2.964621e-08  0.000010  ***          cornification
#  GO:0098609         9             25  4.477433e-04  0.104921    -     cell-cell adhesion
#  GO:0008544         6             11  8.198124e-04  0.144082    -  epidermis development
#  GO:0007155        12             53  1.728909e-03  0.243085    -          cell adhesion
#
# Other Gene number: 1092
# ############################## Cluster 17 ##############################
#
# Cell Num: 41
# Gene Num: 92
# Not Zero: 210
# Cluster 17 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                   Astrocyte           4.1416    1.2
# ------------------------------------------------------------
#           (Natural killer T (NKT) cell)(3.5174)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 92 Group2: 1064
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                              go_name
#  GO:0008233         5              5  0.000525  0.062509   -                                                   peptidase activity
#  GO:0015037         2              1  0.017833  0.403963   -                            peptide disulfide oxidoreductase activity
#  GO:0005046         2              1  0.017833  0.403963   -                                                KDEL sequence binding
#  GO:0003756         2              1  0.017833  0.403963   -                                 protein disulfide isomerase activity
#  GO:0004579         2              1  0.017833  0.403963   -  dolichyl-diphosphooligosaccharide-protein glycotransferase activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                               go_name
#  GO:0005783        37             75  1.063483e-16  1.244275e-14  ***                                 endoplasmic reticulum
#  GO:0005789        33             62  1.608780e-15  9.411363e-14  ***                        endoplasmic reticulum membrane
#  GO:0005793        10              5  1.369464e-08  5.340909e-07  ***  endoplasmic reticulum-Golgi intermediate compartment
#  GO:0030176         8              6  2.418918e-06  7.075335e-05  ***  integral component of endoplasmic reticulum membrane
#  GO:0030134         6              2  5.345625e-06  1.250876e-04  ***            COPII-coated ER to Golgi transport vesicle
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                                                go_name
#  GO:0006888        12             12  3.916860e-08  0.000017  ***              endoplasmic reticulum to Golgi vesicle-mediated transport
#  GO:0006890         8              3  1.626040e-07  0.000036  ***  retrograde vesicle-mediated transport, Golgi to endoplasmic reticulum
#  GO:0030433         7              3  1.600236e-06  0.000236  ***                                       ubiquitin-dependent ERAD pathway
#  GO:0030970         6              2  5.345625e-06  0.000592  ***                            retrograde protein transport, ER to cytosol
#  GO:0006465         5              1  1.621112e-05  0.001436   **                                              signal peptide processing
#
# Other Gene number: 1064
# ############################## Cluster 18 ##############################
#
# Cell Num: 176
# Gene Num: 94
# Not Zero: 572
# Cluster 18 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                Endothelial cell       9.6456    1.8
# ------------------------------------------------------------
#              (Mesenchymal stem cell)   (5.3605)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 94 Group2: 1069
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                  go_name
#  GO:0008565         3              4  0.014096  0.471294   -                             protein transporter activity
#  GO:0048185         2              1  0.018381  0.471294   -                                          activin binding
#  GO:0005520         2              1  0.018381  0.471294   -                       insulin-like growth factor binding
#  GO:0034713         2              1  0.018381  0.471294   -  type I transforming growth factor beta receptor binding
#  GO:0005201         5             17  0.027040  0.471294   -              extracellular matrix structural constituent
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                   go_name
#  GO:0005886        49            336  0.000055  0.007067  **                           plasma membrane
#  GO:0005925        18             68  0.000073  0.007067  **                            focal adhesion
#  GO:0062023        13             44  0.000343  0.022159   *  collagen-containing extracellular matrix
#  GO:0043235         7             15  0.001124  0.045885   *                          receptor complex
#  GO:0009986        17             81  0.001288  0.045885   *                              cell surface
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value       q-value  sig                                                          go_name
#  GO:0001525        17             22  7.724354e-10  5.499740e-07  ***                                                     angiogenesis
#  GO:0001570         5              3  1.434112e-04  5.105438e-02    -                                                   vasculogenesis
#  GO:0030198        10             28  5.210398e-04  1.236601e-01    -                                extracellular matrix organization
#  GO:0007155        13             48  6.980173e-04  1.242471e-01    -                                                    cell adhesion
#  GO:0007156         4              3  1.161579e-03  1.428009e-01    -  homophilic cell adhesion via plasma membrane adhesion molecules
#
# Other Gene number: 1069
# ############################## Cluster 19 ##############################
#
# Cell Num: 95
# Gene Num: 96
# Not Zero: 376
# Cluster 19 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good                  B cell            8.8405    5.2
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 96 Group2: 1090
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                                go_name
#  GO:0003723        21            116  0.001833  0.319856   -                                                            RNA binding
#  GO:0000978        11             43  0.002794  0.319856   -      RNA polymerase II proximal promoter sequence-specific DNA binding
#  GO:0070888         3              2  0.004563  0.348332   -                                                          E-box binding
#  GO:0000981        12             64  0.015430  0.449282   -  DNA-binding transcription factor activity, RNA polymerase II-specific
#  GO:0000977         5             17  0.027222  0.449282   -      RNA polymerase II regulatory region sequence-specific DNA binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                       go_name
#  GO:0005634        47            368  0.002319  0.493842   -                       nucleus
#  GO:0005667         6             18  0.009770  0.512759   -  transcription factor complex
#  GO:0000788         2              1  0.018437  0.512759   -            nuclear nucleosome
#  GO:0016020        25            187  0.024120  0.512759   -                      membrane
#  GO:0035578         4             12  0.034414  0.512759   -       azurophil granule lumen
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                        go_name
#  GO:1903208         3              1  0.001939  0.418873   -  negative regulation of hydrogen peroxide-induced neuron death
#  GO:0060348         4              5  0.003705  0.418873   -                                               bone development
#  GO:0032148         3              2  0.004563  0.418873   -                        activation of protein kinase B activity
#  GO:0001933         3              2  0.004563  0.418873   -                 negative regulation of protein phosphorylation
#  GO:0050885         3              3  0.008592  0.418873   -                      neuromuscular process controlling balance
#
# Other Gene number: 1090
# ############################## Cluster 2 ##############################
#
# Cell Num: 104
# Gene Num: 42
# Not Zero: 267
# Cluster 2 Gene number: 48
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                     T cell            5.0592    1.1
# ------------------------------------------------------------
#                 (Microglial cell)      (4.6114)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 42 Group2: 1120
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                          go_name
#  GO:0042605         4             14  0.003126  0.114731   -          peptide antigen binding
#  GO:0042288         3              6  0.003173  0.114731   -      MHC class I protein binding
#  GO:0004857         2              1  0.003741  0.114731   -        enzyme inhibitor activity
#  GO:0031726         2              2  0.007311  0.168150   -  CCR1 chemokine receptor binding
#  GO:0043621         2              3  0.011906  0.178391   -         protein self-association
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                               go_name
#  GO:0042612         4              5  0.000163  0.009313  **                                           MHC class I protein complex
#  GO:0009897        10             71  0.000365  0.010388   *                                      external side of plasma membrane
#  GO:0031901         5             17  0.000809  0.011882   *                                               early endosome membrane
#  GO:0055038         4              9  0.000834  0.011882   *                                           recycling endosome membrane
#  GO:0071556         4             13  0.002497  0.028462   *  integral component of lumenal side of endoplasmic reticulum membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value  sig                                                                                                            go_name
#  GO:0060337         8             17  0.000001  0.000338  ***                                                                                type I interferon signaling pathway
#  GO:0006955        12             68  0.000010  0.001715   **                                                                                                    immune response
#  GO:0002486         4              4  0.000093  0.007465   **  antigen processing and presentation of endogenous peptide antigen via MHC class I via ER pathway, TAP-independent
#  GO:0002476         4              4  0.000093  0.007465   **                                 antigen processing and presentation of endogenous peptide antigen via MHC class Ib
#  GO:0045071         5             10  0.000111  0.007465   **                                                                    negative regulation of viral genome replication
#
# Other Gene number: 1120
# ############################## Cluster 20 ##############################
#
# Cell Num: 97
# Gene Num: 93
# Not Zero: 338
# Cluster 20 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                   Stem cell           6.7798    1.7
# ------------------------------------------------------------
#                 (Progenitor cell)      (3.8824)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 93 Group2: 1084
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                 go_name
#  GO:0004129         5              5  0.000508  0.111847   -           cytochrome-c oxidase activity
#  GO:0003723        20            110  0.001666  0.157093   -                             RNA binding
#  GO:0097110         5              8  0.002142  0.157093   -                scaffold protein binding
#  GO:0004298         3              3  0.008021  0.386908   -   threonine-type endopeptidase activity
#  GO:0003743         3              4  0.013239  0.386908   -  translation initiation factor activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                       go_name
#  GO:0016327         4              1  0.000172  0.016521   *  apicolateral plasma membrane
#  GO:0070062        43            302  0.000235  0.016521   *         extracellular exosome
#  GO:0005882         7             11  0.000238  0.016521   *         intermediate filament
#  GO:0005743         7             13  0.000509  0.026442   *  mitochondrial inner membrane
#  GO:0005829        49            394  0.001499  0.062353   -                       cytosol
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                            go_name
#  GO:1902600         5              7  0.001405  0.412319   -                                     proton transmembrane transport
#  GO:0070268         7             18  0.002267  0.412319   -                                                      cornification
#  GO:0010498         3              3  0.008021  0.412319   -                              proteasomal protein catabolic process
#  GO:0010499         3              4  0.013239  0.412319   -        proteasomal ubiquitin-independent protein catabolic process
#  GO:0043161         4              9  0.015008  0.412319   -  proteasome-mediated ubiquitin-dependent protein catabolic process
#
# Other Gene number: 1084
# ############################## Cluster 21 ##############################
#
# Cell Num: 47
# Gene Num: 22
# Not Zero: 66
# Cluster 21 Gene number: 33
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good             Microglial cell        5.1354    2.1
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 22 Group2: 1127
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                               go_name
#  GO:0030280         2              4  0.005014  0.179972   -   structural constituent of epidermis
#  GO:0004252         3             18  0.006487  0.179972   -    serine-type endopeptidase activity
#  GO:0019957         2              7  0.011621  0.179972   -                 C-C chemokine binding
#  GO:0004197         2              7  0.011621  0.179972   -  cysteine-type endopeptidase activity
#  GO:0043130         2              9  0.017346  0.179972   -                     ubiquitin binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value  q-value sig                  go_name
#  GO:0001533         2             11  0.024035  0.21125   -       cornified envelope
#  GO:0005575         2             11  0.024035  0.21125   -       cellular_component
#  GO:0005615         7            157  0.027582  0.21125   -      extracellular space
#  GO:0005764         3             36  0.035628  0.21125   -                 lysosome
#  GO:0000178         1              1  0.037944  0.21125   -  exosome (RNase complex)
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                     go_name
#  GO:0018149         3              7  0.000671  0.117502   -                       peptide cross-linking
#  GO:0045616         2              2  0.002053  0.161794   -  regulation of keratinocyte differentiation
#  GO:0035987         2              4  0.005014  0.161794   -             endodermal cell differentiation
#  GO:0030574         2              4  0.005014  0.161794   -                  collagen catabolic process
#  GO:0071345         2              9  0.017346  0.161794   -      cellular response to cytokine stimulus
#
# Other Gene number: 1127
# ############################## Cluster 22 ##############################
#
# Cell Num: 118
# Gene Num: 87
# Not Zero: 339
# Cluster 22 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                   Mast cell           7.3099    1.6
# ------------------------------------------------------------
#             (Hematopoietic stem cell)  (4.5537)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 87 Group2: 1068
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                   go_name
#  GO:0004674         6             15  0.003321  0.338847   -  protein serine/threonine kinase activity
#  GO:0005524        14             76  0.005237  0.338847   -                               ATP binding
#  GO:0046872        14             78  0.006428  0.338847   -                         metal ion binding
#  GO:0000287         4              9  0.012693  0.338847   -                     magnesium ion binding
#  GO:0004181         2              1  0.016013  0.338847   -          metallocarboxypeptidase activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                 go_name
#  GO:0031088         3              1  0.001565  0.270708   -                         platelet dense granule membrane
#  GO:0008021         3              4  0.011579  0.575424   -                                        synaptic vesicle
#  GO:0044233         2              1  0.016013  0.575424   -  mitochondria-associated endoplasmic reticulum membrane
#  GO:0005635         5             16  0.016769  0.575424   -                                        nuclear envelope
#  GO:0031965         5             17  0.020438  0.575424   -                                        nuclear membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                      go_name
#  GO:0051968         3              1  0.001565  0.398852   -  positive regulation of synaptic transmission, glutamatergic
#  GO:0042759         3              2  0.003699  0.398852   -                   long-chain fatty acid biosynthetic process
#  GO:0006468         8             30  0.005625  0.398852   -                                      protein phosphorylation
#  GO:0006811         3              3  0.006995  0.398852   -                                                ion transport
#  GO:0019371         3              3  0.006995  0.398852   -                                       cyclooxygenase pathway
#
# Other Gene number: 1068
# ############################## Cluster 3 ##############################
#
# Cell Num: 112
# Gene Num: 90
# Not Zero: 432
# Cluster 3 Gene number: 98
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good                  B cell            10.2561   8.1
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 90 Group2: 1069
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                          go_name
#  GO:0032395         5              3  0.000118  0.017555   *                                   MHC class II receptor activity
#  GO:0023026         6             12  0.001609  0.079934   -                             MHC class II protein complex binding
#  GO:0042605         6             12  0.001609  0.079934   -                                          peptide antigen binding
#  GO:0005085         3              4  0.012608  0.420762   -                       guanyl-nucleotide exchange factor activity
#  GO:0000980         4              9  0.014120  0.420762   -  RNA polymerase II distal enhancer sequence-specific DNA binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value  sig                                     go_name
#  GO:0042613         9              8  0.000001  0.000139  ***                MHC class II protein complex
#  GO:0030658         7              6  0.000016  0.001094   **                  transport vesicle membrane
#  GO:0030669         7              7  0.000030  0.001367   **  clathrin-coated endocytic vesicle membrane
#  GO:0005765        11             27  0.000071  0.002440   **                          lysosomal membrane
#  GO:0032588         7             11  0.000213  0.004888   **                trans-Golgi network membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                                                                            go_name
#  GO:0050853        10              6  2.668841e-08  0.000015  ***                                                  B cell receptor signaling pathway
#  GO:0006959         9             11  5.724269e-06  0.001637   **                                                            humoral immune response
#  GO:0042113         6              3  1.297195e-05  0.002473   **                                                                  B cell activation
#  GO:0019886         9             15  3.428617e-05  0.004903   **  antigen processing and presentation of exogenous peptide antigen via MHC class II
#  GO:0019722         6             11  1.143773e-03  0.112894    -                                                         calcium-mediated signaling
#
# Other Gene number: 1069
# ############################## Cluster 4 ##############################
#
# Cell Num: 63
# Gene Num: 25
# Not Zero: 109
# Cluster 4 Gene number: 27
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good             Microglial cell        6.9649    3.6
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 25 Group2: 1118
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                          go_name
#  GO:0016493         2              5  0.009023  0.187601   -                                  C-C chemokine receptor activity
#  GO:0005068         2              5  0.009023  0.187601   -  transmembrane receptor protein tyrosine kinase adaptor activity
#  GO:0019956         2              5  0.009023  0.187601   -                                                chemokine binding
#  GO:0019957         2              6  0.011870  0.187601   -                                            C-C chemokine binding
#  GO:0008009         2              8  0.018570  0.187601   -                                               chemokine activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                          go_name
#  GO:0043025         3             27  0.025421  0.454491   -                               neuronal cell body
#  GO:0005943         1              1  0.043285  0.454491   -  phosphatidylinositol 3-kinase complex, class IA
#  GO:0061827         1              1  0.043285  0.454491   -                                       sperm head
#  GO:1990578         1              1  0.043285  0.454491   -       perinuclear endoplasmic reticulum membrane
#  GO:0000790         2             20  0.081241  0.593376   -                                nuclear chromatin
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                            go_name
#  GO:0060326         3             13  0.004294  0.195576   -                                    cell chemotaxis
#  GO:0030900         2              3  0.004414  0.195576   -                              forebrain development
#  GO:0007186         5             51  0.005901  0.195576   -       G protein-coupled receptor signaling pathway
#  GO:0050850         2              4  0.006532  0.195576   -  positive regulation of calcium-mediated signaling
#  GO:0002250         4             32  0.006544  0.195576   -                           adaptive immune response
#
# Other Gene number: 1118
# ############################## Cluster 5 ##############################
#
# Cell Num: 86
# Gene Num: 46
# Not Zero: 238
# Cluster 5 Gene number: 51
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?          Natural killer T (NKT) cell  4.2840    1.3
# ------------------------------------------------------------
#                  (T helper cell)       (3.3619)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 46 Group2: 1112
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                 go_name
#  GO:0003746         5              5  0.000017  0.002108  **  translation elongation factor activity
#  GO:0005164         3              5  0.002859  0.174422   -  tumor necrosis factor receptor binding
#  GO:0005125         4             14  0.004437  0.180426   -                       cytokine activity
#  GO:0035591         2              2  0.008806  0.268587   -              signaling adaptor activity
#  GO:0035091         2              3  0.014306  0.306583   -            phosphatidylinositol binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                             go_name
#  GO:0005853         3              2  0.000556  0.053347   -  eukaryotic translation elongation factor 1 complex
#  GO:0005737        23            352  0.008566  0.220019   -                                           cytoplasm
#  GO:0022627         2              2  0.008806  0.220019   -                   cytosolic small ribosomal subunit
#  GO:0005634        24            376  0.009167  0.220019   -                                             nucleus
#  GO:0030665         2              5  0.028552  0.474640   -                    clathrin-coated vesicle membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                       go_name
#  GO:0006414         5              4  0.000009  0.004077  **                                      translational elongation
#  GO:0071864         2              1  0.004517  0.258620   -      positive regulation of cell proliferation in bone marrow
#  GO:0033089         2              1  0.004517  0.258620   -       positive regulation of T cell differentiation in thymus
#  GO:0046632         2              1  0.004517  0.258620   -                             alpha-beta T cell differentiation
#  GO:0071866         2              1  0.004517  0.258620   -  negative regulation of apoptotic process in bone marrow cell
#
# Other Gene number: 1112
# ############################## Cluster 6 ##############################
#
# Cell Num: 1
# Gene Num: 1
# Not Zero: 1
# Cluster 6 Gene number: 8
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good               Goblet cell          0.2671
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 1 Group2: 1130
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig               go_name
#  GO:0030246         1             24  0.022104  0.044209   *  carbohydrate binding
#  GO:0005515         1            779  0.689655  0.689655   -       protein binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig  go_name
#  GO:0005829         1            417  0.369584  0.369584   -  cytosol
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Other Gene number: 1130
# ############################## Cluster 7 ##############################
#
# Cell Num: 126
# Gene Num: 97
# Not Zero: 515
# Cluster 7 Gene number: 100
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good                  B cell            8.9067    2.2
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 97 Group2: 1062
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                               go_name
#  GO:0042605         6             13  0.003261  0.207258   -               peptide antigen binding
#  GO:0023026         6             13  0.003261  0.207258   -  MHC class II protein complex binding
#  GO:0030145         3              2  0.005024  0.207258   -                 manganese ion binding
#  GO:0005506         3              2  0.005024  0.207258   -                      iron ion binding
#  GO:0042802        17             95  0.008348  0.275500   -             identical protein binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                       go_name
#  GO:0042613         8             10  0.000039  0.003397  **  MHC class II protein complex
#  GO:0005765        12             28  0.000047  0.003397  **            lysosomal membrane
#  GO:1904724         6              7  0.000313  0.014811   *        tertiary granule lumen
#  GO:0032588         7             12  0.000507  0.014811   *  trans-Golgi network membrane
#  GO:0030658         6              8  0.000511  0.014811   *    transport vesicle membrane
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                                                            go_name
#  GO:0043312        22             70  0.000002  0.001076  **                                                           neutrophil degranulation
#  GO:0019886        10             16  0.000018  0.006243  **  antigen processing and presentation of exogenous peptide antigen via MHC class II
#  GO:0042102         7             14  0.001016  0.229944   -                                        positive regulation of T cell proliferation
#  GO:0006935         6             11  0.001709  0.290075   -                                                                         chemotaxis
#  GO:0030225         3              1  0.002140  0.290585   -                                                         macrophage differentiation
#
# Other Gene number: 1062
# ############################## Cluster 8 ##############################
#
# Cell Num: 135
# Gene Num: 93
# Not Zero: 369
# Cluster 8 Gene number: 99
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                   Basal cell          6.0048    1.3
# ------------------------------------------------------------
#               (Embryonic stem cell)    (4.4729)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 93 Group2: 1083
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                  go_name
#  GO:0008106         5              2  0.000052  0.003999  **   alcohol dehydrogenase (NADP+) activity
#  GO:0016491         5              2  0.000052  0.003999  **                  oxidoreductase activity
#  GO:0005198         9             21  0.000293  0.015149   *             structural molecule activity
#  GO:0004032         4              2  0.000487  0.018885   *  alditol:NADP+ 1-oxidoreductase activity
#  GO:0043295         3              1  0.001809  0.040064   *                      glutathione binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                  go_name
#  GO:0001533         6             11  0.001264  0.085642   -       cornified envelope
#  GO:0016328         5              7  0.001411  0.085642   -  lateral plasma membrane
#  GO:0005922         3              1  0.001809  0.085642   -         connexin complex
#  GO:0005882         6             14  0.003255  0.115556   -    intermediate filament
#  GO:0005615        23            148  0.004673  0.132716   -      extracellular space
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num       p-value   q-value  sig                         go_name
#  GO:0001523         7              2  4.924755e-07  0.000316  ***      retinoid metabolic process
#  GO:0006805         8              7  4.633071e-06  0.001485   **    xenobiotic metabolic process
#  GO:0070268        11             21  1.357707e-05  0.002901   **                   cornification
#  GO:0044597         4              1  1.729395e-04  0.022171    *  daunorubicin metabolic process
#  GO:0044598         4              1  1.729395e-04  0.022171    *   doxorubicin metabolic process
#
# Other Gene number: 1083
# ############################## Cluster 9 ##############################
#
# Cell Num: 97
# Gene Num: 47
# Not Zero: 230
# Cluster 9 Gene number: 52
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?              Natural killer cell      7.0462    1.6
# ------------------------------------------------------------
#           (Natural killer T (NKT) cell)(4.4315)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 47 Group2: 1109
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                    go_name
#  GO:0004888         7             20  0.000056  0.006483  **  transmembrane signaling receptor activity
#  GO:1990405         3              2  0.000596  0.014486   *                    protein antigen binding
#  GO:0023024         3              2  0.000596  0.014486   *        MHC class I protein complex binding
#  GO:0048020         3              2  0.000596  0.014486   *             CCR chemokine receptor binding
#  GO:0030246         6             22  0.000624  0.014486   *                       carbohydrate binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                          go_name
#  GO:0044194         2              1  0.004731  0.307547   -                                cytolytic granule
#  GO:0043235         3             20  0.063051  0.470929   -                                 receptor complex
#  GO:0030014         1              1  0.079696  0.470929   -                                 CCR4-NOT complex
#  GO:1990578         1              1  0.079696  0.470929   -       perinuclear endoplasmic reticulum membrane
#  GO:0005943         1              1  0.079696  0.470929   -  phosphatidylinositol 3-kinase complex, class IA
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#         ids  gene_num  othergene_num   p-value   q-value sig                                          go_name
#  GO:0071356         5             12  0.000384  0.079683   -       cellular response to tumor necrosis factor
#  GO:0006968         5             16  0.001117  0.079683   -                        cellular defense response
#  GO:0010820         3              3  0.001158  0.079683   -         positive regulation of T cell chemotaxis
#  GO:0032703         3              3  0.001158  0.079683   -  negative regulation of interleukin-2 production
#  GO:0048247         3              3  0.001158  0.079683   -                            lymphocyte chemotaxis
#
# Other Gene number: 1109
# ################################################################################
#
# #Cluster Type Celltype Score Times
# ['0', '?', 'T cell|Natural killer cell', '6.416679890173055|4.89304737253182', 1.3113872402287532]
# ['1', '?', 'T helper cell|Natural killer T (NKT) cell', '2.341946701493572|2.341946701493572', 1.0]
# ['10', '?', 'T cell|Natural killer T (NKT) cell', '7.655209304317028|5.976039501816364', 1.2809837187304896]
# ['11', '?', 'T cell|Natural killer T (NKT) cell', '7.238051585998569|5.241639388660388', 1.380875533264872]
# ['12', '?', 'Natural killer T (NKT) cell|T helper1 (Th1) cell', '5.006032900780562|3.935275426406395', 1.2720921303726787]
# ['13', 'N', '-', '-', '-']
# ['14', 'Good', 'Natural killer T (NKT) cell', 5.265686466214344, 3.1294782595519792]
# ['15', '?', 'Mesenchymal stem cell|Stem cell', '7.54646208935744|4.026965761474616', 1.873982183199401]
# ['16', 'Good', 'Basal cell', 8.867482137954381, 2.553588955029222]
# ['17', '?', 'Astrocyte|Natural killer T (NKT) cell', '4.141613418826587|3.517415083585177', 1.1774593900374097]
# ['18', '?', 'Endothelial cell|Mesenchymal stem cell', '9.64556042093968|5.360456989609257', 1.799391439878483]
# ['19', 'Good', 'B cell', 8.84050688389043, 5.1625351071671695]
# ['2', '?', 'T cell|Microglial cell', '5.059240312224758|4.611414862117644', 1.097112375159728]
# ['20', '?', 'Stem cell|Progenitor cell', '6.779790352526641|3.882361157659156', 1.7463059404330303]
# ['21', 'Good', 'Microglial cell', 5.135416013596932, 2.1410735353862838]
# ['22', '?', 'Mast cell|Hematopoietic stem cell', '7.309885502691608|4.553707079756475', 1.605260368017024]
# ['3', 'Good', 'B cell', 10.256068961540127, 8.10744121584214]
# ['4', 'Good', 'Microglial cell', 6.964909147741527, 3.6186682703023108]
# ['5', '?', 'Natural killer T (NKT) cell|T helper cell', '4.284032847755692|3.3618696145564093', 1.2743007132717015]
# ['6', 'Good', 'Goblet cell', 0.2670585925550672, '-']
# ['7', 'Good', 'B cell', 8.906666436178881, 2.157634837243236]
# ['8', '?', 'Basal cell|Embryonic stem cell', '6.004783773653284|4.472904162441219', 1.3424798644413602]
# ['9', '?', 'Natural killer cell|Natural killer T (NKT) cell', '7.0462375280578815|4.431518315848034', 1.590027847308916]
